# %% [markdown]
# # Course Project - Part 1
#
# This is the main notebook to generate the smoke estimates for Alexandria from 1964-2021. This notebook also builds a predictive model at the end to predict the estimates for future upto 2050.
#
# ## License
#
# Snippets from this code to get distances for fires was developed by Dr. David W. McDonald for use in DATA 512, a course in the UW MS Data Science degree program. This code is provided under the [Creative Commons](https://creativecommons.org) [CC-BY license](https://creativecommons.org/licenses/by/4.0/). Revision 1.1 - August 16, 2024
#
# Rest of the code is under MIT license
#
# ## Dependencies
#
# This notebook has dependencies on [Pyproj](https://pyproj4.github.io/pyproj/stable/index.html), the [geojson](https://pypi.org/project/geojson/) module and on the wildfire user, compute distance modules present in the helper folder. I have added the pip install commands for reproducibility and it will capture it for future use.

# %%
# %%capture
# %pip install geojson
# %pip install matplotlib
# %pip install numpy
# %pip install statsmodels
# %pip install sklearn

# %%
#
#    IMPORTS
# 

#    Import some standard python modules
import os, json, time
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# Stats model are used to predict the time series smoke estimate data
from statsmodels.tsa.statespace.sarimax import SARIMAX
from statsmodels.tsa.stattools import adfuller

#    The 'wildfire' module is a user module. This module is available from the course website. The module
#    includes one object, a Reader, that can be used to read the GeoJSON files associated with the
#    wildefire dataset. The module also contains a sample datafile that is GeoJSON compliant and that
#    contains a small number of wildfires extracted from the main wildfire dataset.
#    
from helpers.wildfire.Reader import Reader as WFReader
# import the process fire module to compute average and smallest distance
from helpers.compute_distance import process_fire_feature

# Using multiprocessing will help speed up the process of reading data as it parallelizes the task
import multiprocessing

# The 'requests' module is a distribution module for making web requests. If you do not have it already, you'll need to install it
import requests

# %% [markdown]
# ### Step 0: Data acquisition
#
# You should get the [Combined wildland fire datasets for the United States and certain territories, 1800s-Present (combined wildland fire polygons)](https://www.sciencebase.gov/catalog/item/61aa537dd34eb622f699df81) dataset. This dataset was collected and aggregated by the US Geological Survey. The dataset is relatively well documented. The dataset provides fire polygons in ArcGIS and GeoJSON formats.
#
# The data should be downloaded and put under the `raw_data/<USGS_Wildland_Fire_Combined_Dataset.json>` to run the below cell. The size of the data is 2.7GB thus I have not uploaded it to github.

# %% [markdown]
# I am analyzing forest fires in [Alexandria, VA](https://en.wikipedia.org/wiki/Alexandria,_Virginia). Alexandria is an independent city (not bound to any county), in the northern region of the Commonwealth of Virginia, United States. The latitude and longitude information is acquired from Wikipedia.

# %%
DATA_FILENAME = "../raw_data/USGS_Wildland_Fire_Combined_Dataset.json"

# I have added only one city Alexandria in the city locations as my analysis is only for this one city
CITY_LOCATIONS = {
    'Alexandria' :     {'city'   : 'Alexandria',
                       'latlon' : [38.820450, -77.050552] }}

# %%
#
#    This bit of code opens a new wildfire reader, gets the header information and prints it to the screen
#
print(f"Attempting to open '{DATA_FILENAME}' with wildfire.Reader() object")
wfreader = WFReader(DATA_FILENAME)
print()
#
#    Now print the header - it contains some useful information
#
header_dict = wfreader.header()
header_keys = list(header_dict.keys())
print("The header has the following keys:")
print(header_keys)
print()
print("Header Dictionary")
print(json.dumps(header_dict,indent=4))
# Out:
# Attempting to open '../raw_data/USGS_Wildland_Fire_Combined_Dataset.json' with wildfire.Reader() object
#
# The header has the following keys:
# ['displayFieldName', 'fieldAliases', 'geometryType', 'spatialReference', 'fields']
#
# Header Dictionary
# {
#     "displayFieldName": "",
#     "fieldAliases": {
#         "OBJECTID": "OBJECTID",
#         "USGS_Assigned_ID": "USGS Assigned ID",
#         "Assigned_Fire_Type": "Assigned Fire Type",
#         "Fire_Year": "Fire Year",
#         "Fire_Polygon_Tier": "Fire Polygon Tier",
#         "Fire_Attribute_Tiers": "Fire Attribute Tiers",
#         "GIS_Acres": "GIS_Acres",
#         "GIS_Hectares": "GIS_Hectares",
#         "Source_Datasets": "Source Datasets",
#         "Listed_Fire_Types": "Listed Fire Types",
#         "Listed_Fire_Names": "Listed Fire Names",
#         "Listed_Fire_Codes": "Listed Fire Codes",
#         "Listed_Fire_IDs": "Listed Fire IDs",
#         "Listed_Fire_IRWIN_IDs": "Listed Fire IRWIN IDs",
#         "Listed_Fire_Dates": "Listed Fire Dates",
#         "Listed_Fire_Causes": "Listed Fire Causes",
#         "Listed_Fire_Cause_Class": "Listed Fire Cause Class",
#         "Listed_Rx_Reported_Acres": "Listed Rx Reported Acres",
#         "Listed_Map_Digitize_Methods": "Listed Map Digitize Methods",
#         "Listed_Notes": "Listed Notes",
#         "Processing_Notes": "Processing Notes",
#         "Wildfire_Notice": "Wildfire Notice",
#         "Prescribed_Burn_Notice": "Prescribed Burn Notice",
#         "Wildfire_and_Rx_Flag": "Wildfire and Rx Flag",
#         "Overlap_Within_1_or_2_Flag": "Overlap Within 1 or 2 Years Flag",
#         "Circleness_Scale": "Circleness Scale",
#         "Circle_Flag": "Circle Flag",
#         "Exclude_From_Summary_Rasters": "Exclude From Summary Rasters",
#         "Shape_Length": "Shape_Length",
#         "Shape_Area": "Shape_Area"
#     },
#     "geometryType": "esriGeometryPolygon",
#     "spatialReference": {
#         "wkid": 102008,
#         "latestWkid": 102008
#     },
#     "fields": [
#         {
#             "name": "OBJECTID",
#             "type": "esriFieldTypeOID",
#             "alias": "OBJECTID"
#         },
#         {
#             "name": "USGS_Assigned_ID",
#             "type": "esriFieldTypeInteger",
#             "alias": "USGS Assigned ID"
#         },
#         {
#             "name": "Assigned_Fire_Type",
#             "type": "esriFieldTypeString",
#             "alias": "Assigned Fire Type",
#             "length": 100
#         },
#         {
#             "name": "Fire_Year",
#             "type": "esriFieldTypeSmallInteger",
#             "alias": "Fire Year"
#         },
#         {
#             "name": "Fire_Polygon_Tier",
#             "type": "esriFieldTypeSmallInteger",
#             "alias": "Fire Polygon Tier"
#         },
#         {
#             "name": "Fire_Attribute_Tiers",
#             "type": "esriFieldTypeString",
#             "alias": "Fire Attribute Tiers",
#             "length": 30000
#         },
#         {
#             "name": "GIS_Acres",
#             "type": "esriFieldTypeDouble",
#             "alias": "GIS_Acres"
#         },
#         {
#             "name": "GIS_Hectares",
#             "type": "esriFieldTypeDouble",
#             "alias": "GIS_Hectares"
#         },
#         {
#             "name": "Source_Datasets",
#             "type": "esriFieldTypeString",
#             "alias": "Source Datasets",
#             "length": 500000
#         },
#         {
#             "name": "Listed_Fire_Types",
#             "type": "esriFieldTypeString",
#             "alias": "Listed Fire Types",
#             "length": 100000
#         },
#         {
#             "name": "Listed_Fire_Names",
#             "type": "esriFieldTypeString",
#             "alias": "Listed Fire Names",
#             "length": 100000
#         },
#         {
#             "name": "Listed_Fire_Codes",
#             "type": "esriFieldTypeString",
#             "alias": "Listed Fire Codes",
#             "length": 100000
#         },
#         {
#             "name": "Listed_Fire_IDs",
#             "type": "esriFieldTypeString",
#             "alias": "Listed Fire IDs",
#             "length": 30000
#         },
#         {
#             "name": "Listed_Fire_IRWIN_IDs",
#             "type": "esriFieldTypeString",
#             "alias": "Listed Fire IRWIN IDs",
#             "length": 30000
#         },
#         {
#             "name": "Listed_Fire_Dates",
#             "type": "esriFieldTypeString",
#             "alias": "Listed Fire Dates",
#             "length": 500000
#         },
#         {
#             "name": "Listed_Fire_Causes",
#             "type": "esriFieldTypeString",
#             "alias": "Listed Fire Causes",
#             "length": 100000
#         },
#         {
#             "name": "Listed_Fire_Cause_Class",
#             "type": "esriFieldTypeString",
#             "alias": "Listed Fire Cause Class",
#             "length": 100000
#         },
#         {
#             "name": "Listed_Rx_Reported_Acres",
#             "type": "esriFieldTypeString",
#             "alias": "Listed Rx Reported Acres",
#             "length": 10000
#         },
#         {
#             "name": "Listed_Map_Digitize_Methods",
#             "type": "esriFieldTypeString",
#             "alias": "Listed Map Digitize Methods",
#             "length": 100000
#         },
#         {
#             "name": "Listed_Notes",
#             "type": "esriFieldTypeString",
#             "alias": "Listed Notes",
#             "length": 30000
#         },
#         {
#             "name": "Processing_Notes",
#             "type": "esriFieldTypeString",
#             "alias": "Processing Notes",
#             "length": 30000
#         },
#         {
#             "name": "Wildfire_Notice",
#             "type": "esriFieldTypeString",
#             "alias": "Wildfire Notice",
#             "length": 700
#         },
#         {
#             "name": "Prescribed_Burn_Notice",
#             "type": "esriFieldTypeString",
#             "alias": "Prescribed Burn Notice",
#             "length": 700
#         },
#         {
#             "name": "Wildfire_and_Rx_Flag",
#             "type": "esriFieldTypeString",
#             "alias": "Wildfire and Rx Flag",
#             "length": 1000
#         },
#         {
#             "name": "Overlap_Within_1_or_2_Flag",
#             "type": "esriFieldTypeString",
#             "alias": "Overlap Within 1 or 2 Years Flag",
#             "length": 8000
#         },
#         {
#             "name": "Circleness_Scale",
#             "type": "esriFieldTypeDouble",
#             "alias": "Circleness Scale"
#         },
#         {
#             "name": "Circle_Flag",
#             "type": "esriFieldTypeSmallInteger",
#             "alias": "Circle Flag"
#         },
#         {
#             "name": "Exclude_From_Summary_Rasters",
#             "type": "esriFieldTypeString",
#             "alias": "Exclude From Summary Rasters",
#             "length": 3
#         },
#         {
#             "name": "Shape_Length",
#             "type": "esriFieldTypeDouble",
#             "alias": "Shape_Length"
#         },
#         {
#             "name": "Shape_Area",
#             "type": "esriFieldTypeDouble",
#             "alias": "Shape_Area"
#         }
#     ]
# }

# %% [markdown]
# The below code is a snippet from Dr. Mcdonalds reference code.

# %%
#
#    This sample code will load the whole sample (extracted data) file, 
#
MAX_FEATURE_LOAD = 100
feature_list = list()
feature_count = 0
# A rewind() on the reader object makes sure we're at the start of the feature list
# This way, we can execute this cell multiple times and get the same result 
wfreader.rewind()
# Now, read through each of the features, saving them as dictionaries into a list
feature = wfreader.next()
while feature:
    feature_list.append(feature)
    feature_count += 1
    # As we're loading a lot of features, print progress
    if (feature_count % 100) == 0:
        print(f"Loaded {feature_count} features")

    feature = wfreader.next()
#
#    Print the number of items (features) we think we loaded
print(f"Loaded a total of {feature_count} features")
#
#    Just a validation check - did all the items we loaded get into the list?
print(f"Variable 'feature_list' contains {len(feature_list)} features")
# Out:
# Loaded 100 features
# Loaded 200 features
# Loaded 300 features
# Loaded 400 features
# Loaded 500 features
# Loaded 600 features
# Loaded 700 features
# Loaded 800 features
# Loaded 900 features
# Loaded 1000 features
# Loaded 1100 features
# Loaded 1200 features
# Loaded 1300 features
# Loaded 1400 features
# Loaded 1500 features
# Loaded 1600 features
# Loaded 1700 features
# Loaded 1800 features
# Loaded 1900 features
# Loaded 2000 features
# Loaded 2100 features
# Loaded 2200 features
# Loaded 2300 features
# Loaded 2400 features
# Loaded 2500 features
# Loaded 2600 features
# Loaded 2700 features
# Loaded 2800 features
# Loaded 2900 features
# Loaded 3000 features
# Loaded 3100 features
# Loaded 3200 features
# Loaded 3300 features
# Loaded 3400 features
# Loaded 3500 features
# Loaded 3600 features
# Loaded 3700 features
# Loaded 3800 features
# Loaded 3900 features
# Loaded 4000 features
# Loaded 4100 features
# Loaded 4200 features
# Loaded 4300 features
# Loaded 4400 features
# Loaded 4500 features
# Loaded 4600 features
# Loaded 4700 features
# Loaded 4800 features
# Loaded 4900 features
# Loaded 5000 features
# Loaded 5100 features
# Loaded 5200 features
# Loaded 5300 features
# Loaded 5400 features
# Loaded 5500 features
# Loaded 5600 features
# Loaded 5700 features
# Loaded 5800 features
# Loaded 5900 features
# Loaded 6000 features
# Loaded 6100 features
# Loaded 6200 features
# Loaded 6300 features
# Loaded 6400 features
# Loaded 6500 features
# Loaded 6600 features
# Loaded 6700 features
# Loaded 6800 features
# Loaded 6900 features
# Loaded 7000 features
# Loaded 7100 features
# Loaded 7200 features
# Loaded 7300 features
# Loaded 7400 features
# Loaded 7500 features
# Loaded 7600 features
# Loaded 7700 features
# Loaded 7800 features
# Loaded 7900 features
# Loaded 8000 features
# Loaded 8100 features
# Loaded 8200 features
# Loaded 8300 features
# Loaded 8400 features
# Loaded 8500 features
# Loaded 8600 features
# Loaded 8700 features
# Loaded 8800 features
# Loaded 8900 features
# Loaded 9000 features
# Loaded 9100 features
# Loaded 9200 features
# Loaded 9300 features
# Loaded 9400 features
# Loaded 9500 features
# Loaded 9600 features
# Loaded 9700 features
# Loaded 9800 features
# Loaded 9900 features
# Loaded 10000 features
# Loaded 10100 features
# Loaded 10200 features
# Loaded 10300 features
# Loaded 10400 features
# Loaded 10500 features
# Loaded 10600 features
# Loaded 10700 features
# Loaded 10800 features
# Loaded 10900 features
# Loaded 11000 features
# Loaded 11100 features
# Loaded 11200 features
# Loaded 11300 features
# Loaded 11400 features
# Loaded 11500 features
# Loaded 11600 features
# Loaded 11700 features
# Loaded 11800 features
# Loaded 11900 features
# Loaded 12000 features
# Loaded 12100 features
# Loaded 12200 features
# Loaded 12300 features
# Loaded 12400 features
# Loaded 12500 features
# Loaded 12600 features
# Loaded 12700 features
# Loaded 12800 features
# Loaded 12900 features
# Loaded 13000 features
# Loaded 13100 features
# Loaded 13200 features
# Loaded 13300 features
# Loaded 13400 features
# Loaded 13500 features
# Loaded 13600 features
# Loaded 13700 features
# Loaded 13800 features
# Loaded 13900 features
# Loaded 14000 features
# Loaded 14100 features
# Loaded 14200 features
# Loaded 14300 features
# Loaded 14400 features
# Loaded 14500 features
# Loaded 14600 features
# Loaded 14700 features
# Loaded 14800 features
# Loaded 14900 features
# Loaded 15000 features
# Loaded 15100 features
# Loaded 15200 features
# Loaded 15300 features
# Loaded 15400 features
# Loaded 15500 features
# Loaded 15600 features
# Loaded 15700 features
# Loaded 15800 features
# Loaded 15900 features
# Loaded 16000 features
# Loaded 16100 features
# Loaded 16200 features
# Loaded 16300 features
# Loaded 16400 features
# Loaded 16500 features
# Loaded 16600 features
# Loaded 16700 features
# Loaded 16800 features
# Loaded 16900 features
# Loaded 17000 features
# Loaded 17100 features
# Loaded 17200 features
# Loaded 17300 features
# Loaded 17400 features
# Loaded 17500 features
# Loaded 17600 features
# Loaded 17700 features
# Loaded 17800 features
# Loaded 17900 features
# Loaded 18000 features
# Loaded 18100 features
# Loaded 18200 features
# Loaded 18300 features
# Loaded 18400 features
# Loaded 18500 features
# Loaded 18600 features
# Loaded 18700 features
# Loaded 18800 features
# Loaded 18900 features
# Loaded 19000 features
# Loaded 19100 features
# Loaded 19200 features
# Loaded 19300 features
# Loaded 19400 features
# Loaded 19500 features
# Loaded 19600 features
# Loaded 19700 features
# Loaded 19800 features
# Loaded 19900 features
# Loaded 20000 features
# Loaded 20100 features
# Loaded 20200 features
# Loaded 20300 features
# Loaded 20400 features
# Loaded 20500 features
# Loaded 20600 features
# Loaded 20700 features
# Loaded 20800 features
# Loaded 20900 features
# Loaded 21000 features
# Loaded 21100 features
# Loaded 21200 features
# Loaded 21300 features
# Loaded 21400 features
# Loaded 21500 features
# Loaded 21600 features
# Loaded 21700 features
# Loaded 21800 features
# Loaded 21900 features
# Loaded 22000 features
# Loaded 22100 features
# Loaded 22200 features
# Loaded 22300 features
# Loaded 22400 features
# Loaded 22500 features
# Loaded 22600 features
# Loaded 22700 features
# Loaded 22800 features
# Loaded 22900 features
# Loaded 23000 features
# Loaded 23100 features
# Loaded 23200 features
# Loaded 23300 features
# Loaded 23400 features
# Loaded 23500 features
# Loaded 23600 features
# Loaded 23700 features
# Loaded 23800 features
# Loaded 23900 features
# Loaded 24000 features
# Loaded 24100 features
# Loaded 24200 features
# Loaded 24300 features
# Loaded 24400 features
# Loaded 24500 features
# Loaded 24600 features
# Loaded 24700 features
# Loaded 24800 features
# Loaded 24900 features
# Loaded 25000 features
# Loaded 25100 features
# Loaded 25200 features
# Loaded 25300 features
# Loaded 25400 features
# Loaded 25500 features
# Loaded 25600 features
# Loaded 25700 features
# Loaded 25800 features
# Loaded 25900 features
# Loaded 26000 features
# Loaded 26100 features
# Loaded 26200 features
# Loaded 26300 features
# Loaded 26400 features
# Loaded 26500 features
# Loaded 26600 features
# Loaded 26700 features
# Loaded 26800 features
# Loaded 26900 features
# Loaded 27000 features
# Loaded 27100 features
# Loaded 27200 features
# Loaded 27300 features
# Loaded 27400 features
# Loaded 27500 features
# Loaded 27600 features
# Loaded 27700 features
# Loaded 27800 features
# Loaded 27900 features
# Loaded 28000 features
# Loaded 28100 features
# Loaded 28200 features
# Loaded 28300 features
# Loaded 28400 features
# Loaded 28500 features
# Loaded 28600 features
# Loaded 28700 features
# Loaded 28800 features
# Loaded 28900 features
# Loaded 29000 features
# Loaded 29100 features
# Loaded 29200 features
# Loaded 29300 features
# Loaded 29400 features
# Loaded 29500 features
# Loaded 29600 features
# Loaded 29700 features
# Loaded 29800 features
# Loaded 29900 features
# Loaded 30000 features
# Loaded 30100 features
# Loaded 30200 features
# Loaded 30300 features
# Loaded 30400 features
# Loaded 30500 features
# Loaded 30600 features
# Loaded 30700 features
# Loaded 30800 features
# Loaded 30900 features
# Loaded 31000 features
# Loaded 31100 features
# Loaded 31200 features
# Loaded 31300 features
# Loaded 31400 features
# Loaded 31500 features
# Loaded 31600 features
# Loaded 31700 features
# Loaded 31800 features
# Loaded 31900 features
# Loaded 32000 features
# Loaded 32100 features
# Loaded 32200 features
# Loaded 32300 features
# Loaded 32400 features
# Loaded 32500 features
# Loaded 32600 features
# Loaded 32700 features
# Loaded 32800 features
# Loaded 32900 features
# Loaded 33000 features
# Loaded 33100 features
# Loaded 33200 features
# Loaded 33300 features
# Loaded 33400 features
# Loaded 33500 features
# Loaded 33600 features
# Loaded 33700 features
# Loaded 33800 features
# Loaded 33900 features
# Loaded 34000 features
# Loaded 34100 features
# Loaded 34200 features
# Loaded 34300 features
# Loaded 34400 features
# Loaded 34500 features
# Loaded 34600 features
# Loaded 34700 features
# Loaded 34800 features
# Loaded 34900 features
# Loaded 35000 features
# Loaded 35100 features
# Loaded 35200 features
# Loaded 35300 features
# Loaded 35400 features
# Loaded 35500 features
# Loaded 35600 features
# Loaded 35700 features
# Loaded 35800 features
# Loaded 35900 features
# Loaded 36000 features
# Loaded 36100 features
# Loaded 36200 features
# Loaded 36300 features
# Loaded 36400 features
# Loaded 36500 features
# Loaded 36600 features
# Loaded 36700 features
# Loaded 36800 features
# Loaded 36900 features
# Loaded 37000 features
# Loaded 37100 features
# Loaded 37200 features
# Loaded 37300 features
# Loaded 37400 features
# Loaded 37500 features
# Loaded 37600 features
# Loaded 37700 features
# Loaded 37800 features
# Loaded 37900 features
# Loaded 38000 features
# Loaded 38100 features
# Loaded 38200 features
# Loaded 38300 features
# Loaded 38400 features
# Loaded 38500 features
# Loaded 38600 features
# Loaded 38700 features
# Loaded 38800 features
# Loaded 38900 features
# Loaded 39000 features
# Loaded 39100 features
# Loaded 39200 features
# Loaded 39300 features
# Loaded 39400 features
# Loaded 39500 features
# Loaded 39600 features
# Loaded 39700 features
# Loaded 39800 features
# Loaded 39900 features
# Loaded 40000 features
# Loaded 40100 features
# Loaded 40200 features
# Loaded 40300 features
# Loaded 40400 features
# Loaded 40500 features
# Loaded 40600 features
# Loaded 40700 features
# Loaded 40800 features
# Loaded 40900 features
# Loaded 41000 features
# Loaded 41100 features
# Loaded 41200 features
# Loaded 41300 features
# Loaded 41400 features
# Loaded 41500 features
# Loaded 41600 features
# Loaded 41700 features
# Loaded 41800 features
# Loaded 41900 features
# Loaded 42000 features
# Loaded 42100 features
# Loaded 42200 features
# Loaded 42300 features
# Loaded 42400 features
# Loaded 42500 features
# Loaded 42600 features
# Loaded 42700 features
# Loaded 42800 features
# Loaded 42900 features
# Loaded 43000 features
# Loaded 43100 features
# Loaded 43200 features
# Loaded 43300 features
# Loaded 43400 features
# Loaded 43500 features
# Loaded 43600 features
# Loaded 43700 features
# Loaded 43800 features
# Loaded 43900 features
# Loaded 44000 features
# Loaded 44100 features
# Loaded 44200 features
# Loaded 44300 features
# Loaded 44400 features
# Loaded 44500 features
# Loaded 44600 features
# Loaded 44700 features
# Loaded 44800 features
# Loaded 44900 features
# Loaded 45000 features
# Loaded 45100 features
# Loaded 45200 features
# Loaded 45300 features
# Loaded 45400 features
# Loaded 45500 features
# Loaded 45600 features
# Loaded 45700 features
# Loaded 45800 features
# Loaded 45900 features
# Loaded 46000 features
# Loaded 46100 features
# Loaded 46200 features
# Loaded 46300 features
# Loaded 46400 features
# Loaded 46500 features
# Loaded 46600 features
# Loaded 46700 features
# Loaded 46800 features
# Loaded 46900 features
# Loaded 47000 features
# Loaded 47100 features
# Loaded 47200 features
# Loaded 47300 features
# Loaded 47400 features
# Loaded 47500 features
# Loaded 47600 features
# Loaded 47700 features
# Loaded 47800 features
# Loaded 47900 features
# Loaded 48000 features
# Loaded 48100 features
# Loaded 48200 features
# Loaded 48300 features
# Loaded 48400 features
# Loaded 48500 features
# Loaded 48600 features
# Loaded 48700 features
# Loaded 48800 features
# Loaded 48900 features
# Loaded 49000 features
# Loaded 49100 features
# Loaded 49200 features
# Loaded 49300 features
# Loaded 49400 features
# Loaded 49500 features
# Loaded 49600 features
# Loaded 49700 features
# Loaded 49800 features
# Loaded 49900 features
# Loaded 50000 features
# Loaded 50100 features
# Loaded 50200 features
# Loaded 50300 features
# Loaded 50400 features
# Loaded 50500 features
# Loaded 50600 features
# Loaded 50700 features
# Loaded 50800 features
# Loaded 50900 features
# Loaded 51000 features
# Loaded 51100 features
# Loaded 51200 features
# Loaded 51300 features
# Loaded 51400 features
# Loaded 51500 features
# Loaded 51600 features
# Loaded 51700 features
# Loaded 51800 features
# Loaded 51900 features
# Loaded 52000 features
# Loaded 52100 features
# Loaded 52200 features
# Loaded 52300 features
# Loaded 52400 features
# Loaded 52500 features
# Loaded 52600 features
# Loaded 52700 features
# Loaded 52800 features
# Loaded 52900 features
# Loaded 53000 features
# Loaded 53100 features
# Loaded 53200 features
# Loaded 53300 features
# Loaded 53400 features
# Loaded 53500 features
# Loaded 53600 features
# Loaded 53700 features
# Loaded 53800 features
# Loaded 53900 features
# Loaded 54000 features
# Loaded 54100 features
# Loaded 54200 features
# Loaded 54300 features
# Loaded 54400 features
# Loaded 54500 features
# Loaded 54600 features
# Loaded 54700 features
# Loaded 54800 features
# Loaded 54900 features
# Loaded 55000 features
# Loaded 55100 features
# Loaded 55200 features
# Loaded 55300 features
# Loaded 55400 features
# Loaded 55500 features
# Loaded 55600 features
# Loaded 55700 features
# Loaded 55800 features
# Loaded 55900 features
# Loaded 56000 features
# Loaded 56100 features
# Loaded 56200 features
# Loaded 56300 features
# Loaded 56400 features
# Loaded 56500 features
# Loaded 56600 features
# Loaded 56700 features
# Loaded 56800 features
# Loaded 56900 features
# Loaded 57000 features
# Loaded 57100 features
# Loaded 57200 features
# Loaded 57300 features
# Loaded 57400 features
# Loaded 57500 features
# Loaded 57600 features
# Loaded 57700 features
# Loaded 57800 features
# Loaded 57900 features
# Loaded 58000 features
# Loaded 58100 features
# Loaded 58200 features
# Loaded 58300 features
# Loaded 58400 features
# Loaded 58500 features
# Loaded 58600 features
# Loaded 58700 features
# Loaded 58800 features
# Loaded 58900 features
# Loaded 59000 features
# Loaded 59100 features
# Loaded 59200 features
# Loaded 59300 features
# Loaded 59400 features
# Loaded 59500 features
# Loaded 59600 features
# Loaded 59700 features
# Loaded 59800 features
# Loaded 59900 features
# Loaded 60000 features
# Loaded 60100 features
# Loaded 60200 features
# Loaded 60300 features
# Loaded 60400 features
# Loaded 60500 features
# Loaded 60600 features
# Loaded 60700 features
# Loaded 60800 features
# Loaded 60900 features
# Loaded 61000 features
# Loaded 61100 features
# Loaded 61200 features
# Loaded 61300 features
# Loaded 61400 features
# Loaded 61500 features
# Loaded 61600 features
# Loaded 61700 features
# Loaded 61800 features
# Loaded 61900 features
# Loaded 62000 features
# Loaded 62100 features
# Loaded 62200 features
# Loaded 62300 features
# Loaded 62400 features
# Loaded 62500 features
# Loaded 62600 features
# Loaded 62700 features
# Loaded 62800 features
# Loaded 62900 features
# Loaded 63000 features
# Loaded 63100 features
# Loaded 63200 features
# Loaded 63300 features
# Loaded 63400 features
# Loaded 63500 features
# Loaded 63600 features
# Loaded 63700 features
# Loaded 63800 features
# Loaded 63900 features
# Loaded 64000 features
# Loaded 64100 features
# Loaded 64200 features
# Loaded 64300 features
# Loaded 64400 features
# Loaded 64500 features
# Loaded 64600 features
# Loaded 64700 features
# Loaded 64800 features
# Loaded 64900 features
# Loaded 65000 features
# Loaded 65100 features
# Loaded 65200 features
# Loaded 65300 features
# Loaded 65400 features
# Loaded 65500 features
# Loaded 65600 features
# Loaded 65700 features
# Loaded 65800 features
# Loaded 65900 features
# Loaded 66000 features
# Loaded 66100 features
# Loaded 66200 features
# Loaded 66300 features
# Loaded 66400 features
# Loaded 66500 features
# Loaded 66600 features
# Loaded 66700 features
# Loaded 66800 features
# Loaded 66900 features
# Loaded 67000 features
# Loaded 67100 features
# Loaded 67200 features
# Loaded 67300 features
# Loaded 67400 features
# Loaded 67500 features
# Loaded 67600 features
# Loaded 67700 features
# Loaded 67800 features
# Loaded 67900 features
# Loaded 68000 features
# Loaded 68100 features
# Loaded 68200 features
# Loaded 68300 features
# Loaded 68400 features
# Loaded 68500 features
# Loaded 68600 features
# Loaded 68700 features
# Loaded 68800 features
# Loaded 68900 features
# Loaded 69000 features
# Loaded 69100 features
# Loaded 69200 features
# Loaded 69300 features
# Loaded 69400 features
# Loaded 69500 features
# Loaded 69600 features
# Loaded 69700 features
# Loaded 69800 features
# Loaded 69900 features
# Loaded 70000 features
# Loaded 70100 features
# Loaded 70200 features
# Loaded 70300 features
# Loaded 70400 features
# Loaded 70500 features
# Loaded 70600 features
# Loaded 70700 features
# Loaded 70800 features
# Loaded 70900 features
# Loaded 71000 features
# Loaded 71100 features
# Loaded 71200 features
# Loaded 71300 features
# Loaded 71400 features
# Loaded 71500 features
# Loaded 71600 features
# Loaded 71700 features
# Loaded 71800 features
# Loaded 71900 features
# Loaded 72000 features
# Loaded 72100 features
# Loaded 72200 features
# Loaded 72300 features
# Loaded 72400 features
# Loaded 72500 features
# Loaded 72600 features
# Loaded 72700 features
# Loaded 72800 features
# Loaded 72900 features
# Loaded 73000 features
# Loaded 73100 features
# Loaded 73200 features
# Loaded 73300 features
# Loaded 73400 features
# Loaded 73500 features
# Loaded 73600 features
# Loaded 73700 features
# Loaded 73800 features
# Loaded 73900 features
# Loaded 74000 features
# Loaded 74100 features
# Loaded 74200 features
# Loaded 74300 features
# Loaded 74400 features
# Loaded 74500 features
# Loaded 74600 features
# Loaded 74700 features
# Loaded 74800 features
# Loaded 74900 features
# Loaded 75000 features
# Loaded 75100 features
# Loaded 75200 features
# Loaded 75300 features
# Loaded 75400 features
# Loaded 75500 features
# Loaded 75600 features
# Loaded 75700 features
# Loaded 75800 features
# Loaded 75900 features
# Loaded 76000 features
# Loaded 76100 features
# Loaded 76200 features
# Loaded 76300 features
# Loaded 76400 features
# Loaded 76500 features
# Loaded 76600 features
# Loaded 76700 features
# Loaded 76800 features
# Loaded 76900 features
# Loaded 77000 features
# Loaded 77100 features
# Loaded 77200 features
# Loaded 77300 features
# Loaded 77400 features
# Loaded 77500 features
# Loaded 77600 features
# Loaded 77700 features
# Loaded 77800 features
# Loaded 77900 features
# Loaded 78000 features
# Loaded 78100 features
# Loaded 78200 features
# Loaded 78300 features
# Loaded 78400 features
# Loaded 78500 features
# Loaded 78600 features
# Loaded 78700 features
# Loaded 78800 features
# Loaded 78900 features
# Loaded 79000 features
# Loaded 79100 features
# Loaded 79200 features
# Loaded 79300 features
# Loaded 79400 features
# Loaded 79500 features
# Loaded 79600 features
# Loaded 79700 features
# Loaded 79800 features
# Loaded 79900 features
# Loaded 80000 features
# Loaded 80100 features
# Loaded 80200 features
# Loaded 80300 features
# Loaded 80400 features
# Loaded 80500 features
# Loaded 80600 features
# Loaded 80700 features
# Loaded 80800 features
# Loaded 80900 features
# Loaded 81000 features
# Loaded 81100 features
# Loaded 81200 features
# Loaded 81300 features
# Loaded 81400 features
# Loaded 81500 features
# Loaded 81600 features
# Loaded 81700 features
# Loaded 81800 features
# Loaded 81900 features
# Loaded 82000 features
# Loaded 82100 features
# Loaded 82200 features
# Loaded 82300 features
# Loaded 82400 features
# Loaded 82500 features
# Loaded 82600 features
# Loaded 82700 features
# Loaded 82800 features
# Loaded 82900 features
# Loaded 83000 features
# Loaded 83100 features
# Loaded 83200 features
# Loaded 83300 features
# Loaded 83400 features
# Loaded 83500 features
# Loaded 83600 features
# Loaded 83700 features
# Loaded 83800 features
# Loaded 83900 features
# Loaded 84000 features
# Loaded 84100 features
# Loaded 84200 features
# Loaded 84300 features
# Loaded 84400 features
# Loaded 84500 features
# Loaded 84600 features
# Loaded 84700 features
# Loaded 84800 features
# Loaded 84900 features
# Loaded 85000 features
# Loaded 85100 features
# Loaded 85200 features
# Loaded 85300 features
# Loaded 85400 features
# Loaded 85500 features
# Loaded 85600 features
# Loaded 85700 features
# Loaded 85800 features
# Loaded 85900 features
# Loaded 86000 features
# Loaded 86100 features
# Loaded 86200 features
# Loaded 86300 features
# Loaded 86400 features
# Loaded 86500 features
# Loaded 86600 features
# Loaded 86700 features
# Loaded 86800 features
# Loaded 86900 features
# Loaded 87000 features
# Loaded 87100 features
# Loaded 87200 features
# Loaded 87300 features
# Loaded 87400 features
# Loaded 87500 features
# Loaded 87600 features
# Loaded 87700 features
# Loaded 87800 features
# Loaded 87900 features
# Loaded 88000 features
# Loaded 88100 features
# Loaded 88200 features
# Loaded 88300 features
# Loaded 88400 features
# Loaded 88500 features
# Loaded 88600 features
# Loaded 88700 features
# Loaded 88800 features
# Loaded 88900 features
# Loaded 89000 features
# Loaded 89100 features
# Loaded 89200 features
# Loaded 89300 features
# Loaded 89400 features
# Loaded 89500 features
# Loaded 89600 features
# Loaded 89700 features
# Loaded 89800 features
# Loaded 89900 features
# Loaded 90000 features
# Loaded 90100 features
# Loaded 90200 features
# Loaded 90300 features
# Loaded 90400 features
# Loaded 90500 features
# Loaded 90600 features
# Loaded 90700 features
# Loaded 90800 features
# Loaded 90900 features
# Loaded 91000 features
# Loaded 91100 features
# Loaded 91200 features
# Loaded 91300 features
# Loaded 91400 features
# Loaded 91500 features
# Loaded 91600 features
# Loaded 91700 features
# Loaded 91800 features
# Loaded 91900 features
# Loaded 92000 features
# Loaded 92100 features
# Loaded 92200 features
# Loaded 92300 features
# Loaded 92400 features
# Loaded 92500 features
# Loaded 92600 features
# Loaded 92700 features
# Loaded 92800 features
# Loaded 92900 features
# Loaded 93000 features
# Loaded 93100 features
# Loaded 93200 features
# Loaded 93300 features
# Loaded 93400 features
# Loaded 93500 features
# Loaded 93600 features
# Loaded 93700 features
# Loaded 93800 features
# Loaded 93900 features
# Loaded 94000 features
# Loaded 94100 features
# Loaded 94200 features
# Loaded 94300 features
# Loaded 94400 features
# Loaded 94500 features
# Loaded 94600 features
# Loaded 94700 features
# Loaded 94800 features
# Loaded 94900 features
# Loaded 95000 features
# Loaded 95100 features
# Loaded 95200 features
# Loaded 95300 features
# Loaded 95400 features
# Loaded 95500 features
# Loaded 95600 features
# Loaded 95700 features
# Loaded 95800 features
# Loaded 95900 features
# Loaded 96000 features
# Loaded 96100 features
# Loaded 96200 features
# Loaded 96300 features
# Loaded 96400 features
# Loaded 96500 features
# Loaded 96600 features
# Loaded 96700 features
# Loaded 96800 features
# Loaded 96900 features
# Loaded 97000 features
# Loaded 97100 features
# Loaded 97200 features
# Loaded 97300 features
# Loaded 97400 features
# Loaded 97500 features
# Loaded 97600 features
# Loaded 97700 features
# Loaded 97800 features
# Loaded 97900 features
# Loaded 98000 features
# Loaded 98100 features
# Loaded 98200 features
# Loaded 98300 features
# Loaded 98400 features
# Loaded 98500 features
# Loaded 98600 features
# Loaded 98700 features
# Loaded 98800 features
# Loaded 98900 features
# Loaded 99000 features
# Loaded 99100 features
# Loaded 99200 features
# Loaded 99300 features
# Loaded 99400 features
# Loaded 99500 features
# Loaded 99600 features
# Loaded 99700 features
# Loaded 99800 features
# Loaded 99900 features
# Loaded 100000 features
# Loaded 100100 features
# Loaded 100200 features
# Loaded 100300 features
# Loaded 100400 features
# Loaded 100500 features
# Loaded 100600 features
# Loaded 100700 features
# Loaded 100800 features
# Loaded 100900 features
# Loaded 101000 features
# Loaded 101100 features
# Loaded 101200 features
# Loaded 101300 features
# Loaded 101400 features
# Loaded 101500 features
# Loaded 101600 features
# Loaded 101700 features
# Loaded 101800 features
# Loaded 101900 features
# Loaded 102000 features
# Loaded 102100 features
# Loaded 102200 features
# Loaded 102300 features
# Loaded 102400 features
# Loaded 102500 features
# Loaded 102600 features
# Loaded 102700 features
# Loaded 102800 features
# Loaded 102900 features
# Loaded 103000 features
# Loaded 103100 features
# Loaded 103200 features
# Loaded 103300 features
# Loaded 103400 features
# Loaded 103500 features
# Loaded 103600 features
# Loaded 103700 features
# Loaded 103800 features
# Loaded 103900 features
# Loaded 104000 features
# Loaded 104100 features
# Loaded 104200 features
# Loaded 104300 features
# Loaded 104400 features
# Loaded 104500 features
# Loaded 104600 features
# Loaded 104700 features
# Loaded 104800 features
# Loaded 104900 features
# Loaded 105000 features
# Loaded 105100 features
# Loaded 105200 features
# Loaded 105300 features
# Loaded 105400 features
# Loaded 105500 features
# Loaded 105600 features
# Loaded 105700 features
# Loaded 105800 features
# Loaded 105900 features
# Loaded 106000 features
# Loaded 106100 features
# Loaded 106200 features
# Loaded 106300 features
# Loaded 106400 features
# Loaded 106500 features
# Loaded 106600 features
# Loaded 106700 features
# Loaded 106800 features
# Loaded 106900 features
# Loaded 107000 features
# Loaded 107100 features
# Loaded 107200 features
# Loaded 107300 features
# Loaded 107400 features
# Loaded 107500 features
# Loaded 107600 features
# Loaded 107700 features
# Loaded 107800 features
# Loaded 107900 features
# Loaded 108000 features
# Loaded 108100 features
# Loaded 108200 features
# Loaded 108300 features
# Loaded 108400 features
# Loaded 108500 features
# Loaded 108600 features
# Loaded 108700 features
# Loaded 108800 features
# Loaded 108900 features
# Loaded 109000 features
# Loaded 109100 features
# Loaded 109200 features
# Loaded 109300 features
# Loaded 109400 features
# Loaded 109500 features
# Loaded 109600 features
# Loaded 109700 features
# Loaded 109800 features
# Loaded 109900 features
# Loaded 110000 features
# Loaded 110100 features
# Loaded 110200 features
# Loaded 110300 features
# Loaded 110400 features
# Loaded 110500 features
# Loaded 110600 features
# Loaded 110700 features
# Loaded 110800 features
# Loaded 110900 features
# Loaded 111000 features
# Loaded 111100 features
# Loaded 111200 features
# Loaded 111300 features
# Loaded 111400 features
# Loaded 111500 features
# Loaded 111600 features
# Loaded 111700 features
# Loaded 111800 features
# Loaded 111900 features
# Loaded 112000 features
# Loaded 112100 features
# Loaded 112200 features
# Loaded 112300 features
# Loaded 112400 features
# Loaded 112500 features
# Loaded 112600 features
# Loaded 112700 features
# Loaded 112800 features
# Loaded 112900 features
# Loaded 113000 features
# Loaded 113100 features
# Loaded 113200 features
# Loaded 113300 features
# Loaded 113400 features
# Loaded 113500 features
# Loaded 113600 features
# Loaded 113700 features
# Loaded 113800 features
# Loaded 113900 features
# Loaded 114000 features
# Loaded 114100 features
# Loaded 114200 features
# Loaded 114300 features
# Loaded 114400 features
# Loaded 114500 features
# Loaded 114600 features
# Loaded 114700 features
# Loaded 114800 features
# Loaded 114900 features
# Loaded 115000 features
# Loaded 115100 features
# Loaded 115200 features
# Loaded 115300 features
# Loaded 115400 features
# Loaded 115500 features
# Loaded 115600 features
# Loaded 115700 features
# Loaded 115800 features
# Loaded 115900 features
# Loaded 116000 features
# Loaded 116100 features
# Loaded 116200 features
# Loaded 116300 features
# Loaded 116400 features
# Loaded 116500 features
# Loaded 116600 features
# Loaded 116700 features
# Loaded 116800 features
# Loaded 116900 features
# Loaded 117000 features
# Loaded 117100 features
# Loaded 117200 features
# Loaded 117300 features
# Loaded 117400 features
# Loaded 117500 features
# Loaded 117600 features
# Loaded 117700 features
# Loaded 117800 features
# Loaded 117900 features
# Loaded 118000 features
# Loaded 118100 features
# Loaded 118200 features
# Loaded 118300 features
# Loaded 118400 features
# Loaded 118500 features
# Loaded 118600 features
# Loaded 118700 features
# Loaded 118800 features
# Loaded 118900 features
# Loaded 119000 features
# Loaded 119100 features
# Loaded 119200 features
# Loaded 119300 features
# Loaded 119400 features
# Loaded 119500 features
# Loaded 119600 features
# Loaded 119700 features
# Loaded 119800 features
# Loaded 119900 features
# Loaded 120000 features
# Loaded 120100 features
# Loaded 120200 features
# Loaded 120300 features
# Loaded 120400 features
# Loaded 120500 features
# Loaded 120600 features
# Loaded 120700 features
# Loaded 120800 features
# Loaded 120900 features
# Loaded 121000 features
# Loaded 121100 features
# Loaded 121200 features
# Loaded 121300 features
# Loaded 121400 features
# Loaded 121500 features
# Loaded 121600 features
# Loaded 121700 features
# Loaded 121800 features
# Loaded 121900 features
# Loaded 122000 features
# Loaded 122100 features
# Loaded 122200 features
# Loaded 122300 features
# Loaded 122400 features
# Loaded 122500 features
# Loaded 122600 features
# Loaded 122700 features
# Loaded 122800 features
# Loaded 122900 features
# Loaded 123000 features
# Loaded 123100 features
# Loaded 123200 features
# Loaded 123300 features
# Loaded 123400 features
# Loaded 123500 features
# Loaded 123600 features
# Loaded 123700 features
# Loaded 123800 features
# Loaded 123900 features
# Loaded 124000 features
# Loaded 124100 features
# Loaded 124200 features
# Loaded 124300 features
# Loaded 124400 features
# Loaded 124500 features
# Loaded 124600 features
# Loaded 124700 features
# Loaded 124800 features
# Loaded 124900 features
# Loaded 125000 features
# Loaded 125100 features
# Loaded 125200 features
# Loaded 125300 features
# Loaded 125400 features
# Loaded 125500 features
# Loaded 125600 features
# Loaded 125700 features
# Loaded 125800 features
# Loaded 125900 features
# Loaded 126000 features
# Loaded 126100 features
# Loaded 126200 features
# Loaded 126300 features
# Loaded 126400 features
# Loaded 126500 features
# Loaded 126600 features
# Loaded 126700 features
# Loaded 126800 features
# Loaded 126900 features
# Loaded 127000 features
# Loaded 127100 features
# Loaded 127200 features
# Loaded 127300 features
# Loaded 127400 features
# Loaded 127500 features
# Loaded 127600 features
# Loaded 127700 features
# Loaded 127800 features
# Loaded 127900 features
# Loaded 128000 features
# Loaded 128100 features
# Loaded 128200 features
# Loaded 128300 features
# Loaded 128400 features
# Loaded 128500 features
# Loaded 128600 features
# Loaded 128700 features
# Loaded 128800 features
# Loaded 128900 features
# Loaded 129000 features
# Loaded 129100 features
# Loaded 129200 features
# Loaded 129300 features
# Loaded 129400 features
# Loaded 129500 features
# Loaded 129600 features
# Loaded 129700 features
# Loaded 129800 features
# Loaded 129900 features
# Loaded 130000 features
# Loaded 130100 features
# Loaded 130200 features
# Loaded 130300 features
# Loaded 130400 features
# Loaded 130500 features
# Loaded 130600 features
# Loaded 130700 features
# Loaded 130800 features
# Loaded 130900 features
# Loaded 131000 features
# Loaded 131100 features
# Loaded 131200 features
# Loaded 131300 features
# Loaded 131400 features
# Loaded 131500 features
# Loaded 131600 features
# Loaded 131700 features
# Loaded 131800 features
# Loaded 131900 features
# Loaded 132000 features
# Loaded 132100 features
# Loaded 132200 features
# Loaded 132300 features
# Loaded 132400 features
# Loaded 132500 features
# Loaded 132600 features
# Loaded 132700 features
# Loaded 132800 features
# Loaded 132900 features
# Loaded 133000 features
# Loaded 133100 features
# Loaded 133200 features
# Loaded 133300 features
# Loaded 133400 features
# Loaded 133500 features
# Loaded 133600 features
# Loaded 133700 features
# Loaded 133800 features
# Loaded 133900 features
# Loaded 134000 features
# Loaded 134100 features
# Loaded 134200 features
# Loaded 134300 features
# Loaded 134400 features
# Loaded 134500 features
# Loaded 134600 features
# Loaded 134700 features
# Loaded 134800 features
# Loaded 134900 features
# Loaded 135000 features
# Loaded a total of 135061 features
# Variable 'feature_list' contains 135061 features

# %% [markdown]
# The 'feature_list' variable was created when we read the sample file in a code cell above
#
# The total features in the feature_list are 135061.

# %%
# analyzing single feature in the list, eg feature number 0 in the list
SLOT = 0
wf_feature = feature_list[SLOT]

# Print everyting in this dictionary (i.e., wf_feature) - it's long
print(f"The wildfire feature from slot '{SLOT}' of the loaded 'feature_list'")
print(json.dumps(wf_feature, indent=4))
# Out:
# The wildfire feature from slot '0' of the loaded 'feature_list'
# {
#     "attributes": {
#         "OBJECTID": 1,
#         "USGS_Assigned_ID": 1,
#         "Assigned_Fire_Type": "Wildfire",
#         "Fire_Year": 1860,
#         "Fire_Polygon_Tier": 1,
#         "Fire_Attribute_Tiers": "1 (1)",
#         "GIS_Acres": 3940.20708940724,
#         "GIS_Hectares": 1594.5452365353703,
#         "Source_Datasets": "Comb_National_NIFC_Interagency_Fire_Perimeter_History (1)",
#         "Listed_Fire_Types": "Wildfire (1)",
#         "Listed_Fire_Names": "Big Quilcene River (1)",
#         "Listed_Fire_Codes": "No code provided (1)",
#         "Listed_Fire_IDs": "",
#         "Listed_Fire_IRWIN_IDs": "",
#         "Listed_Fire_Dates": "Listed Other Fire Date(s): 2006-11-02 - NIFC DATE_CUR field (1)",
#         "Listed_Fire_Causes": "",
#         "Listed_Fire_Cause_Class": "Undetermined (1)",
#         "Listed_Rx_Reported_Acres": null,
#         "Listed_Map_Digitize_Methods": "Other (1)",
#         "Listed_Notes": "",
#         "Processing_Notes": "",
#         "Wildfire_Notice": "Wildfire mapping prior to 1984 was inconsistent, infrequent, and done without the aid of more modern fire mapping methods (GPS and satellite imagery). Areas burned prior to 1984 in this dataset represent only a fraction of what actually burned. While areas burned on or after 1984 are much more accurate and complete, errors still can and do occur. This dataset represents the most complete set of digitized polygon fire data available to the public that we, the authors, were able to collect. It is not a complete collection of all wildfires burned during the time period it represents.",
#         "Prescribed_Burn_Notice": "Prescribed fire data in this dataset represents only a fraction of the area burned in prescribed burns across all years due to lack of reporting, particularly on private lands. The missing prescribed burn data becomes more pronounced further back in time, particularly in the southeastern U.S.; however, errors and omissions still occur through the most recent years in this dataset. This dataset represents the most complete set of digitized polygon fire data available to the public that we, the authors, were able to collect. It is not a complete collection of all prescribed burns burned during the time period it represents.",
#         "Wildfire_and_Rx_Flag": null,
#         "Overlap_Within_1_or_2_Flag": null,
#         "Circleness_Scale": 0.04758958417643999,
#         "Circle_Flag": null,
#         "Exclude_From_Summary_Rasters": "No",
#         "Shape_Length": 64888.449849380544,
#         "Shape_Area": 15945452.365353702
#     },
#     "geometry": {
#         "rings": [
#             [
#                 [
#                     -1883775.5960000008,
#                     1194154.1922999993
#                 ],
#                 [
#                     -1883782.4154000003,
#                     1194101.5089999996
#                 ],
#                 [
#                     -1883793.9871999994,
#                     1194061.7941999994
#                 ],
#                 [
#                     -1883787.5426000003,
#                     1194050.4810000006
#                 ],
#                 [
#                     -1883695.0417,
#                     1193891.8584000003
#                 ],
#                 [
#                     -1883692.5623000003,
#                     1193887.8597
#                 ],
#                 [
#                     -1883637.9758000001,
#                     1193793.9821000006
#                 ],
#                 [
#                     -1883607.5802999996,
#                     1193813.3125999998
#                 ],
#                 [
#                     -1883592.7661000006,
#                     1193864.1250999998
#                 ],
#                 [
#                     -1883619.4144000001,
#                     1193899.5493
#                 ],
#                 [
#                     -1883642.5480000004,
#                     1194031.2747000009
#                 ],
#                 [
#                     -1883608.6552000009,
#                     1194104.7665
#                 ],
#                 [
#                     -1883567.0747999996,
#                     1194120.2347999997
#                 ],
#                 [
#                     -1883419.3002000004,
#                     1194076.9736000001
#                 ],
#                 [
#                     -1883354.6516999993,
#                     1193960.8411999997
#                 ],
#                 [
#                     -1883365.3285000008,
#                     1193797.6381
#                 ],
#                 [
#                     -1883429.2529000007,
#                     1193663.7827000003
#                 ],
#                 [
#                     -1883489.7939,
#                     1193625.7153999992
#                 ],
#                 [
#                     -1883561.5198,
#                     1193591.5102999993
#                 ],
#                 [
#                     -1883768.1318999995,
#                     1193597.2643999998
#                 ],
#                 [
#                     -1883769.7292999998,
#                     1193597.114
#                 ],
#                 [
#                     -1883775.7365000006,
#                     1193591.1775000002
#                 ],
#                 [
#                     -1883890.4472000003,
#                     1193479.9444999993
#                 ],
#                 [
#                     -1883981.1689,
#                     1193465.0733000003
#                 ],
#                 [
#                     -1883984.8529000003,
#                     1193468.9334999993
#                 ],
#                 [
#                     -1884000.1383999996,
#                     1193484.5108000003
#                 ],
#                 [
#                     -1884020.1786000002,
#                     1193472.1141
#                 ],
#                 [
#                     -1884059.7780000009,
#                     1193478.7553000003
#                 ],
#                 [
#                     -1884115.1279000007,
#                     1193563.9772999994
#                 ],
#                 [
#                     -1884144.2630000003,
#                     1193546.5176999997
#                 ],
#                 [
#                     -1884176.1905000005,
#                     1193547.0003999993
#                 ],
#                 [
#                     -1884221.921,
#                     1193637.8098000009
#                 ],
#                 [
#                     -1884244.0317000002,
#                     1193644.268100001
#                 ],
#                 [
#                     -1884272.5363999996,
#                     1193601.2130999994
#                 ],
#                 [
#                     -1884323.3753999993,
#                     1193564.1259000003
#                 ],
#                 [
#                     -1884379.6670999993,
#                     1193563.4360000007
#                 ],
#                 [
#                     -1884445.159,
#                     1193530.7414999995
#                 ],
#                 [
#                     -1884488.5263999999,
#                     1193492.0219999999
#                 ],
#                 [
#                     -1884521.7104000002,
#                     1193432.6565000005
#                 ],
#                 [
#                     -1884639.8521999996,
#                     1193467.2627000008
#                 ],
#                 [
#                     -1884616.8002000004,
#                     1193546.7155000009
#                 ],
#                 [
#                     -1884627.4309,
#                     1193592.9112
#                 ],
#                 [
#                     -1884685.5741000008,
#                     1193696.0731000006
#                 ],
#                 [
#                     -1884663.4681000002,
#                     1193827.1842
#                 ],
#                 [
#                     -1884570.2588,
#                     1193955.2087999992
#                 ],
#                 [
#                     -1884566.5253999997,
#                     1194023.1772000007
#                 ],
#                 [
#                     -1884587.2884,
#                     1194089.4596999995
#                 ],
#                 [
#                     -1884557.3039999995,
#                     1194192.8527000006
#                 ],
#                 [
#                     -1884557.7109999992,
#                     1194218.9384000003
#                 ],
#                 [
#                     -1884585.4985000007,
#                     1194261.3028999995
#                 ],
#                 [
#                     -1884622.3805,
#                     1194272.0735
#                 ],
#                 [
#                     -1884728.9868,
#                     1194208.2886999995
#                 ],
#                 [
#                     -1884761.7233000007,
#                     1194123.3735000007
#                 ],
#                 [
#                     -1884746.0463999994,
#                     1194066.8666999992
#                 ],
#                 [
#                     -1884881.7173999995,
#                     1193847.9274000004
#                 ],
#                 [
#                     -1884915.3999000005,
#                     1193814.67
#                 ],
#                 [
#                     -1884998.0084000006,
#                     1193778.6788999997
#                 ],
#                 [
#                     -1884997.1027000006,
#                     1193726.4847999997
#                 ],
#                 [
#                     -1884961.9755000006,
#                     1193681.9756000005
#                 ],
#                 [
#                     -1884939.8910000008,
#                     1193675.4154000003
#                 ],
#                 [
#                     -1884901.1624999996,
#                     1193698.3614000008
#                 ],
#                 [
#                     -1884869.2348999996,
#                     1193697.8796999995
#                 ],
#                 [
#                     -1884849.0108000003,
#                     1193657.1698000003
#                 ],
#                 [
#                     -1884860.5824999996,
#                     1193617.4548000004
#                 ],
#                 [
#                     -1884918.6294999998,
#                     1193583.0245999992
#                 ],
#                 [
#                     -1885033.4809000008,
#                     1193573.5779
#                 ],
#                 [
#                     -1885116.2476000004,
#                     1193536.9704999998
#                 ],
#                 [
#                     -1885123.5873000007,
#                     1193539.1154999994
#                 ],
#                 [
#                     -1885186.7508000005,
#                     1193652.6897999998
#                 ],
#                 [
#                     -1885287.3564,
#                     1193664.9350000005
#                 ],
#                 [
#                     -1885304.92,
#                     1193687.1893000007
#                 ],
#                 [
#                     -1885411.9964000005,
#                     1193925.1819000002
#                 ],
#                 [
#                     -1885410.6488000005,
#                     1193985.0062000006
#                 ],
#                 [
#                     -1885364.4546000008,
#                     1194143.8889000006
#                 ],
#                 [
#                     -1885422.4137999993,
#                     1194523.3335999995
#                 ],
#                 [
#                     -1885414.1338999998,
#                     1194607.0983000007
#                 ],
#                 [
#                     -1885400.3091000002,
#                     1194654.4436000008
#                 ],
#                 [
#                     -1885351.8815000001,
#                     1194683.2868000008
#                 ],
#                 [
#                     -1885309.0064000003,
#                     1194610.5489000008
#                 ],
#                 [
#                     -1885272.0322999991,
#                     1194599.7568999995
#                 ],
#                 [
#                     -1885233.670499999,
#                     1194649.3247999996
#                 ],
#                 [
#                     -1885312.0810000002,
#                     1194792.6559999995
#                 ],
#                 [
#                     -1885330.1438999996,
#                     1194841.0179999992
#                 ],
#                 [
#                     -1885325.9124999996,
#                     1194882.8773999996
#                 ],
#                 [
#                     -1885355.8362000007,
#                     1194917.6897
#                 ],
#                 [
#                     -1885375.3783,
#                     1194905.7145000007
#                 ],
#                 [
#                     -1885432.1119999997,
#                     1194793.0042000003
#                 ],
#                 [
#                     -1885526.7262999993,
#                     1194743.2785999998
#                 ],
#                 [
#                     -1885536.0440999996,
#                     1194711.1942999996
#                 ],
#                 [
#                     -1885492.6698000003,
#                     1194612.3487
#                 ],
#                 [
#                     -1885515.7208999991,
#                     1194532.8962999992
#                 ],
#                 [
#                     -1885511.9816999994,
#                     1194463.2971
#                 ],
#                 [
#                     -1885525.8468999993,
#                     1194415.4157999996
#                 ],
#                 [
#                     -1885571.5080999993,
#                     1194368.5281000007
#                 ],
#                 [
#                     -1885530.9266999997,
#                     1194287.6239
#                 ],
#                 [
#                     -1885588.6985,
#                     1194226.5933999997
#                 ],
#                 [
#                     -1885600.2699999996,
#                     1194186.8784999996
#                 ],
#                 [
#                     -1885574.958900001,
#                     1194136.3945000004
#                 ],
#                 [
#                     -1885581.2607000005,
#                     1194086.8587999996
#                 ],
#                 [
#                     -1885595.6248000003,
#                     1194065.0855
#                 ],
#                 [
#                     -1885641.6931999996,
#                     1194044.2829999998
#                 ],
#                 [
#                     -1885681.0262000002,
#                     1194047.0335000008
#                 ],
#                 [
#                     -1885753.9767000005,
#                     1194016.4002
#                 ],
#                 [
#                     -1885770.5024999995,
#                     1193986.9736000001
#                 ],
#                 [
#                     -1885785.3078000005,
#                     1193853.1823999994
#                 ],
#                 [
#                     -1885808.4505000003,
#                     1193773.7521000002
#                 ],
#                 [
#                     -1885876.7556999996,
#                     1193621.3253000006
#                 ],
#                 [
#                     -1885893.9123,
#                     1193617.4934999999
#                 ],
#                 [
#                     -1885983.3281999994,
#                     1193695.6389000006
#                 ],
#                 [
#                     -1886082.0885000005,
#                     1193741.5964000002
#                 ],
#                 [
#                     -1886121.421599999,
#                     1193744.3462000005
#                 ],
#                 [
#                     -1886281.5545000006,
#                     1193661.8164000008
#                 ],
#                 [
#                     -1886382.1349,
#                     1193674.1592999995
#                 ],
#                 [
#                     -1886476.3222000003,
#                     1193736.0145999994
#                 ],
#                 [
#                     -1886520.636499999,
#                     1193748.9491000008
#                 ],
#                 [
#                     -1886664.6248000003,
#                     1193722.0318999998
#                 ],
#                 [
#                     -1886670.6177999992,
#                     1193784.0000999998
#                 ],
#                 [
#                     -1886698.2744999994,
#                     1193826.8747000005
#                 ],
#                 [
#                     -1886799.4211999997,
#                     1193864.6848000009
#                 ],
#                 [
#                     -1886809.5539999995,
#                     1193884.7705000006
#                 ],
#                 [
#                     -1886803.0291000009,
#                     1193934.796599999
#                 ],
#                 [
#                     -1886769.3465999998,
#                     1193968.0562999994
#                 ],
#                 [
#                     -1886665.0069999993,
#                     1194023.7855999991
#                 ],
#                 [
#                     -1886658.0746,
#                     1194047.7265000008
#                 ],
#                 [
#                     -1886673.2534999996,
#                     1194078.1230999995
#                 ],
#                 [
#                     -1886828.2820999995,
#                     1194123.4832000006
#                 ],
#                 [
#                     -1886857.4175000004,
#                     1194106.0205000006
#                 ],
#                 [
#                     -1886940.0855999999,
#                     1193931.8183999993
#                 ],
#                 [
#                     -1887017.2676,
#                     1193859.3215999994
#                 ],
#                 [
#                     -1887073.1268000007,
#                     1193832.6424000002
#                 ],
#                 [
#                     -1887131.7137000002,
#                     1193823.7791000009
#                 ],
#                 [
#                     -1887220.3427000009,
#                     1193849.6455000006
#                 ],
#                 [
#                     -1887250.2671000008,
#                     1193884.4552999996
#                 ],
#                 [
#                     -1887279.8102000002,
#                     1193893.077299999
#                 ],
#                 [
#                     -1887299.2204,
#                     1193881.6138000004
#                 ],
#                 [
#                     -1887331.5563999992,
#                     1193908.1769999992
#                 ],
#                 [
#                     -1887360.6002999991,
#                     1193890.6910999995
#                 ],
#                 [
#                     -1887400.4914999995,
#                     1193781.3422999997
#                 ],
#                 [
#                     -1887429.4035,
#                     1193764.3695999999
#                 ],
#                 [
#                     -1887486.3016,
#                     1193789.3690000009
#                 ],
#                 [
#                     -1887496.4344999995,
#                     1193809.4542999994
#                 ],
#                 [
#                     -1887514.4067000002,
#                     1193857.7914000005
#                 ],
#                 [
#                     -1887505.4967999998,
#                     1193915.9613000005
#                 ],
#                 [
#                     -1887476.9924999997,
#                     1193959.0190999992
#                 ],
#                 [
#                     -1887394.2510000002,
#                     1193995.5318999998
#                 ],
#                 [
#                     -1887227.6242999993,
#                     1193989.9936999995
#                 ],
#                 [
#                     -1887181.4902,
#                     1194010.673800001
#                 ],
#                 [
#                     -1887172.172700001,
#                     1194042.7585000005
#                 ],
#                 [
#                     -1887257.1757999994,
#                     1194136.1810999997
#                 ],
#                 [
#                     -1887257.5834999997,
#                     1194162.2661000006
#                 ],
#                 [
#                     -1887246.1041,
#                     1194202.0039000008
#                 ],
#                 [
#                     -1887161.1093000006,
#                     1194246.1469
#                 ],
#                 [
#                     -1887125.0414000005,
#                     1194287.5505999997
#                 ],
#                 [
#                     -1887147.6523000002,
#                     1194320.1136000007
#                 ],
#                 [
#                     -1887179.4627999999,
#                     1194320.671599999
#                 ],
#                 [
#                     -1887242.2807999998,
#                     1194269.9485
#                 ],
#                 [
#                     -1887278.8479999993,
#                     1194254.6521000005
#                 ],
#                 [
#                     -1887308.3912000004,
#                     1194263.2739000004
#                 ],
#                 [
#                     -1887323.5704999994,
#                     1194293.6698000003
#                 ],
#                 [
#                     -1887314.3848,
#                     1194325.2412999999
#                 ],
#                 [
#                     -1887324.386,
#                     1194345.8397000004
#                 ],
#                 [
#                     -1887390.3783999998,
#                     1194339.2449999992
#                 ],
#                 [
#                     -1887428.3923000004,
#                     1194401.7126000002
#                 ],
#                 [
#                     -1887457.8441000003,
#                     1194410.3114999998
#                 ],
#                 [
#                     -1887633.2232000008,
#                     1194358.2936000004
#                 ],
#                 [
#                     -1887696.0413000006,
#                     1194307.5693999995
#                 ],
#                 [
#                     -1887712.1591999996,
#                     1194252.0569000002
#                 ],
#                 [
#                     -1887705.7574000005,
#                     1194164.0048999991
#                 ],
#                 [
#                     -1887726.6459,
#                     1194092.2048000004
#                 ],
#                 [
#                     -1887772.7148000002,
#                     1194071.3984999992
#                 ],
#                 [
#                     -1887812.8641999997,
#                     1194126.3148999996
#                 ],
#                 [
#                     -1887846.6476000007,
#                     1194230.6412000004
#                 ],
#                 [
#                     -1887871.420499999,
#                     1194255.5497999992
#                 ],
#                 [
#                     -1887898.3027999997,
#                     1194245.7166000009
#                 ],
#                 [
#                     -1887926.807,
#                     1194202.6585000008
#                 ],
#                 [
#                     -1887945.3101000004,
#                     1194139.0021000002
#                 ],
#                 [
#                     -1887981.8509,
#                     1194123.8073999994
#                 ],
#                 [
#                     -1887997.0305000003,
#                     1194154.2026000004
#                 ],
#                 [
#                     -1888001.2706000004,
#                     1194249.9075000007
#                 ],
#                 [
#                     -1888034.0151000004,
#                     1194302.5541999992
#                 ],
#                 [
#                     -1888132.6206,
#                     1194349.1169000007
#                 ],
#                 [
#                     -1888354.2114000004,
#                     1194413.3370999992
#                 ],
#                 [
#                     -1888435.9102999996,
#                     1194463.1385999992
#                 ],
#                 [
#                     -1888445.6356000006,
#                     1194457.1385999992
#                 ],
#                 [
#                     -1888444.6876999997,
#                     1194405.4825
#                 ],
#                 [
#                     -1888421.6681999993,
#                     1194346.8366
#                 ],
#                 [
#                     -1888430.853599999,
#                     1194315.2651000004
#                 ],
#                 [
#                     -1888467.3293999992,
#                     1194299.9441999998
#                 ],
#                 [
#                     -1888548.5938000008,
#                     1194323.7633999996
#                 ],
#                 [
#                     -1888575.3443,
#                     1194314.4427000005
#                 ],
#                 [
#                     -1888702.9580000006,
#                     1194178.761
#                 ],
#                 [
#                     -1888751.386,
#                     1194149.9115999993
#                 ],
#                 [
#                     -1888793.7243000008,
#                     1194197.0698000006
#                 ],
#                 [
#                     -1888842.2704000007,
#                     1194168.1403
#                 ],
#                 [
#                     -1888848.2649000008,
#                     1194230.1064999998
#                 ],
#                 [
#                     -1888832.0559,
#                     1194285.5965
#                 ],
#                 [
#                     -1888842.2808999997,
#                     1194305.703400001
#                 ],
#                 [
#                     -1888961.3671000004,
#                     1194254.3772999998
#                 ],
#                 [
#                     -1889049.5902999993,
#                     1194254.1510000005
#                 ],
#                 [
#                     -1889152.8759000003,
#                     1194284.398600001
#                 ],
#                 [
#                     -1889223.9421999995,
#                     1194288.0058999993
#                 ],
#                 [
#                     -1889431.2522999998,
#                     1194236.4502000008
#                 ],
#                 [
#                     -1889620.1919999998,
#                     1194248.0362
#                 ],
#                 [
#                     -1889681.9416000005,
#                     1194283.7270999998
#                 ],
#                 [
#                     -1889770.5473999996,
#                     1194309.6849000007
#                 ],
#                 [
#                     -1889834.4058999997,
#                     1194310.6338
#                 ],
#                 [
#                     -1889839.7693000007,
#                     1194347.0052000005
#                 ],
#                 [
#                     -1889750.2003000006,
#                     1194407.0567000005
#                 ],
#                 [
#                     -1889659.6293000001,
#                     1194552.8888000008
#                 ],
#                 [
#                     -1889620.9000000004,
#                     1194575.8421999998
#                 ],
#                 [
#                     -1889525.7441000007,
#                     1194600.0119000003
#                 ],
#                 [
#                     -1889467.9071999993,
#                     1194660.9251000006
#                 ],
#                 [
#                     -1889421.3377999999,
#                     1194655.6276999991
#                 ],
#                 [
#                     -1889411.2041999996,
#                     1194635.5439
#                 ],
#                 [
#                     -1889516.5472,
#                     1194494.0218000002
#                 ],
#                 [
#                     -1889516.1389000006,
#                     1194467.9374000002
#                 ],
#                 [
#                     -1889449.7370999996,
#                     1194448.4539
#                 ],
#                 [
#                     -1889227.1549999993,
#                     1194469.5933999997
#                 ],
#                 [
#                     -1889114.8421999998,
#                     1194497.5958999991
#                 ],
#                 [
#                     -1889024.8915,
#                     1194531.4576999992
#                 ],
#                 [
#                     -1888944.9159999993,
#                     1194586.0194000006
#                 ],
#                 [
#                     -1888950.5026999991,
#                     1194621.9005999994
#                 ],
#                 [
#                     -1888995.2268000003,
#                     1194660.9141000006
#                 ],
#                 [
#                     -1888930.5633000005,
#                     1194745.3564999998
#                 ],
#                 [
#                     -1888921.2460999992,
#                     1194777.4414000008
#                 ],
#                 [
#                     -1888961.3318000007,
#                     1194832.2292999998
#                 ],
#                 [
#                     -1888993.2610999998,
#                     1194832.7047000006
#                 ],
#                 [
#                     -1889114.7327999994,
#                     1194773.2336999997
#                 ],
#                 [
#                     -1889163.6873000003,
#                     1194770.3878000006
#                 ],
#                 [
#                     -1889222.1550999992,
#                     1194899.5940000005
#                 ],
#                 [
#                     -1889274.2851,
#                     1194940.8752999995
#                 ],
#                 [
#                     -1889289.0570999999,
#                     1194945.1846999992
#                 ],
#                 [
#                     -1889317.1646999996,
#                     1195013.6028000005
#                 ],
#                 [
#                     -1889308.3878000006,
#                     1195071.2586000003
#                 ],
#                 [
#                     -1889212.2298000008,
#                     1195181.2084
#                 ],
#                 [
#                     -1889200.6596000008,
#                     1195220.9236999992
#                 ],
#                 [
#                     -1889202.1081000008,
#                     1195298.6860000007
#                 ],
#                 [
#                     -1889220.0556000005,
#                     1195347.1226000004
#                 ],
#                 [
#                     -1889271.7123000007,
#                     1195362.1941
#                 ],
#                 [
#                     -1889376.0537,
#                     1195306.4532999992
#                 ],
#                 [
#                     -1889501.1363999993,
#                     1195317.0888999999
#                 ],
#                 [
#                     -1889554.6503999997,
#                     1195436.0057999995
#                 ],
#                 [
#                     -1889607.1895000003,
#                     1195503.3699999992
#                 ],
#                 [
#                     -1889649.0295000002,
#                     1195524.418299999
#                 ],
#                 [
#                     -1889676.0039000008,
#                     1195514.6054999996
#                 ],
#                 [
#                     -1889724.4586999994,
#                     1195485.6513999999
#                 ],
#                 [
#                     -1889765.1647999994,
#                     1195428.4700000007
#                 ],
#                 [
#                     -1889786.8561000004,
#                     1195271.2774
#                 ],
#                 [
#                     -1889776.3136999998,
#                     1195225.1097999997
#                 ],
#                 [
#                     -1889733.4333999995,
#                     1195152.3838
#                 ],
#                 [
#                     -1889696.4572,
#                     1195141.5998
#                 ],
#                 [
#                     -1889523.3280999996,
#                     1195186.0030000005
#                 ],
#                 [
#                     -1889476.7584000006,
#                     1195180.7060000002
#                 ],
#                 [
#                     -1889439.4656000007,
#                     1195143.8599999994
#                 ],
#                 [
#                     -1889414.7059000004,
#                     1194981.2896999996
#                 ],
#                 [
#                     -1889447.4398999996,
#                     1194896.3715000004
#                 ],
#                 [
#                     -1889505.6853,
#                     1194861.5426000003
#                 ],
#                 [
#                     -1889574.8954000007,
#                     1194761.3017999995
#                 ],
#                 [
#                     -1889604.0311999992,
#                     1194743.836100001
#                 ],
#                 [
#                     -1889646.9110000003,
#                     1194816.5627999995
#                 ],
#                 [
#                     -1889662.6053,
#                     1194872.6298999991
#                 ],
#                 [
#                     -1889684.8092999998,
#                     1194879.1050000004
#                 ],
#                 [
#                     -1889721.2732999995,
#                     1194726.2207999993
#                 ],
#                 [
#                     -1889762.3878000006,
#                     1194695.1235000007
#                 ],
#                 [
#                     -1889786.9768000003,
#                     1194693.4547000006
#                 ],
#                 [
#                     -1889816.9294000007,
#                     1194728.1570999995
#                 ],
#                 [
#                     -1889918.3436999992,
#                     1194930.2122000009
#                 ],
#                 [
#                     -1889940.4562,
#                     1194936.6642000005
#                 ],
#                 [
#                     -1890039.8424999993,
#                     1194870.6338999998
#                 ],
#                 [
#                     -1890083.7243000008,
#                     1194857.579
#                 ],
#                 [
#                     -1890113.1769999992,
#                     1194866.1741000004
#                 ],
#                 [
#                     -1890178.1295999996,
#                     1194945.8871999998
#                 ],
#                 [
#                     -1890199.3061999995,
#                     1195038.2446999997
#                 ],
#                 [
#                     -1890076.3709999993,
#                     1195157.6225000005
#                 ],
#                 [
#                     -1890062.5478000008,
#                     1195204.9685999993
#                 ],
#                 [
#                     -1890087.9540999997,
#                     1195255.4673999995
#                 ],
#                 [
#                     -1890068.9520999994,
#                     1195293.0172000006
#                 ],
#                 [
#                     -1890030.0908000004,
#                     1195316.4844000004
#                 ],
#                 [
#                     -1890072.5628999993,
#                     1195363.1253999993
#                 ],
#                 [
#                     -1890066.0396999996,
#                     1195413.1503999997
#                 ],
#                 [
#                     -1890076.1736999992,
#                     1195433.2336999997
#                 ],
#                 [
#                     -1890150.0351999998,
#                     1195454.7773000002
#                 ],
#                 [
#                     -1890196.4817999993,
#                     1195442.3564999998
#                 ],
#                 [
#                     -1890228.0999999996,
#                     1195434.5650999993
#                 ],
#                 [
#                     -1890242.8723000009,
#                     1195438.8738000002
#                 ],
#                 [
#                     -1890275.1190000009,
#                     1195465.4083999991
#                 ],
#                 [
#                     -1890290.3000000007,
#                     1195495.801000001
#                 ],
#                 [
#                     -1890298.1405999996,
#                     1195524.0506999996
#                 ],
#                 [
#                     -1890291.1173,
#                     1195547.9689000007
#                 ],
#                 [
#                     -1890291.6578000002,
#                     1195573.5395
#                 ],
#                 [
#                     -1890238.0240000002,
#                     1195592.6985
#                 ],
#                 [
#                     -1890218.705,
#                     1195604.1868999992
#                 ],
#                 [
#                     -1890196.9092999995,
#                     1195623.7967000008
#                 ],
#                 [
#                     -1890189.9777000006,
#                     1195647.7376000006
#                 ],
#                 [
#                     -1890215.2927,
#                     1195698.2131999992
#                 ],
#                 [
#                     -1890231.1059000008,
#                     1195754.1992000006
#                 ],
#                 [
#                     -1890224.0826999992,
#                     1195778.1173
#                 ],
#                 [
#                     -1890224.4912999999,
#                     1195804.2013000008
#                 ],
#                 [
#                     -1890171.398,
#                     1195848.9308000002
#                 ],
#                 [
#                     -1890146.9265,
#                     1195850.5204000007
#                 ],
#                 [
#                     -1890132.1542000007,
#                     1195846.2116999999
#                 ],
#                 [
#                     -1890100.7125000004,
#                     1195768.0195000004
#                 ],
#                 [
#                     -1890039.9091999996,
#                     1195750.2514999993
#                 ],
#                 [
#                     -1890028.4173000008,
#                     1195652.4297000002
#                 ],
#                 [
#                     -1890013.2364000008,
#                     1195622.0370000005
#                 ],
#                 [
#                     -1889966.6927000005,
#                     1195616.6384999994
#                 ],
#                 [
#                     -1889901.0803999994,
#                     1195649.4280999992
#                 ],
#                 [
#                     -1889831.8573000003,
#                     1195612.1093000006
#                 ],
#                 [
#                     -1889812.446799999,
#                     1195623.5746999998
#                 ],
#                 [
#                     -1889812.3076000009,
#                     1195627.9072999991
#                 ],
#                 [
#                     -1889810.4726999998,
#                     1195628.9816999994
#                 ],
#                 [
#                     -1889809.1245000008,
#                     1195683.8894999996
#                 ],
#                 [
#                     -1889733.0374999996,
#                     1195703.6072000004
#                 ],
#                 [
#                     -1889718.2653,
#                     1195699.2982
#                 ],
#                 [
#                     -1889687.7718000002,
#                     1195639.0252999999
#                 ],
#                 [
#                     -1889550.3013000004,
#                     1195615.9382000007
#                 ],
#                 [
#                     -1889516.6186999995,
#                     1195649.2010999992
#                 ],
#                 [
#                     -1889516.9001000002,
#                     1195652.6550999992
#                 ],
#                 [
#                     -1889514.6183000002,
#                     1195654.7107999995
#                 ],
#                 [
#                     -1889529.0386999995,
#                     1195823.0190999992
#                 ],
#                 [
#                     -1889513.2930999994,
#                     1195855.478599999
#                 ],
#                 [
#                     -1889483.1338,
#                     1195846.5991999991
#                 ],
#                 [
#                     -1889452.7722999994,
#                     1195785.8126999997
#                 ],
#                 [
#                     -1889413.0940000005,
#                     1195757.1108999997
#                 ],
#                 [
#                     -1889354.5592999998,
#                     1195627.7817000002
#                 ],
#                 [
#                     -1889329.6532000005,
#                     1195603.388699999
#                 ],
#                 [
#                     -1889254.8560000006,
#                     1195667.7480999995
#                 ],
#                 [
#                     -1889251.966,
#                     1195672.9285000004
#                 ],
#                 [
#                     -1889238.1072000004,
#                     1195697.6667999998
#                 ],
#                 [
#                     -1889174.8801000006,
#                     1195722.3106999993
#                 ],
#                 [
#                     -1889123.1580999997,
#                     1195707.1138000004
#                 ],
#                 [
#                     -1889112.6159000006,
#                     1195660.9459000006
#                 ],
#                 [
#                     -1889068.2994,
#                     1195648.0176999997
#                 ],
#                 [
#                     -1889039.1635999996,
#                     1195665.482999999
#                 ],
#                 [
#                     -1889040.9508999996,
#                     1195668.7635999992
#                 ],
#                 [
#                     -1889037.2546999995,
#                     1195671.0153
#                 ],
#                 [
#                     -1889041.8991999999,
#                     1195679.4788000006
#                 ],
#                 [
#                     -1888996.7041999996,
#                     1195756.4009000007
#                 ],
#                 [
#                     -1888981.932,
#                     1195752.0914999992
#                 ],
#                 [
#                     -1888960.7826000005,
#                     1195659.6298999991
#                 ],
#                 [
#                     -1888911.9192999993,
#                     1195662.4984000009
#                 ],
#                 [
#                     -1888823.8151999991,
#                     1195524.6504999995
#                 ],
#                 [
#                     -1888719.5801999997,
#                     1195442.7474000007
#                 ],
#                 [
#                     -1888601.4301999994,
#                     1195408.1667
#                 ],
#                 [
#                     -1888562.7008999996,
#                     1195431.1184999999
#                 ],
#                 [
#                     -1888562.0371000003,
#                     1195435.9762999993
#                 ],
#                 [
#                     -1888560.7005000003,
#                     1195436.6280000005
#                 ],
#                 [
#                     -1888554.1767999995,
#                     1195486.6533000004
#                 ],
#                 [
#                     -1888641.5920000002,
#                     1195710.5793999992
#                 ],
#                 [
#                     -1888629.2705000006,
#                     1195752.8380999994
#                 ],
#                 [
#                     -1888562.8683000002,
#                     1195733.3529000003
#                 ],
#                 [
#                     -1888492.7383999992,
#                     1195643.8380999994
#                 ],
#                 [
#                     -1888448.5138000008,
#                     1195630.9311999995
#                 ],
#                 [
#                     -1888419.3780000005,
#                     1195648.3959
#                 ],
#                 [
#                     -1888417.1291000005,
#                     1195653.7347999997
#                 ],
#                 [
#                     -1888337.2380999997,
#                     1195848.6041
#                 ],
#                 [
#                     -1888335.1863000002,
#                     1195853.5550999995
#                 ],
#                 [
#                     -1888349.0347000007,
#                     1196107.8622999992
#                 ],
#                 [
#                     -1888325.6240999997,
#                     1196164.0808000006
#                 ],
#                 [
#                     -1888296.2398000006,
#                     1196181.3747000005
#                 ],
#                 [
#                     -1888070.2299000006,
#                     1196132.4420999996
#                 ],
#                 [
#                     -1888031.3684999999,
#                     1196155.9064000007
#                 ],
#                 [
#                     -1888032.9726,
#                     1196159.1417999994
#                 ],
#                 [
#                     -1888029.3680000007,
#                     1196161.4159999993
#                 ],
#                 [
#                     -1888039.5017000008,
#                     1196181.5001999997
#                 ],
#                 [
#                     -1888096.3366999999,
#                     1196206.3709999993
#                 ],
#                 [
#                     -1888111.8834000006,
#                     1196236.8559000008
#                 ],
#                 [
#                     -1888095.0151000004,
#                     1196294.9112999998
#                 ],
#                 [
#                     -1888053.4922000002,
#                     1196299.9218000006
#                 ],
#                 [
#                     -1888048.3136999998,
#                     1196290.1249000002
#                 ],
#                 [
#                     -1888028.9947999995,
#                     1196301.6118
#                 ],
#                 [
#                     -1888030.5988999996,
#                     1196304.8472000007
#                 ],
#                 [
#                     -1888026.9943000004,
#                     1196307.1213000007
#                 ],
#                 [
#                     -1888047.3532999996,
#                     1196347.3125999998
#                 ],
#                 [
#                     -1888126.5770999994,
#                     1196405.2342000008
#                 ],
#                 [
#                     -1888205.0899999999,
#                     1196410.5765000004
#                 ],
#                 [
#                     -1888228.5252999999,
#                     1196457.7512999997
#                 ],
#                 [
#                     -1888118.3376000002,
#                     1196517.2816000003
#                 ],
#                 [
#                     -1888068.9605999999,
#                     1196494.4749999996
#                 ],
#                 [
#                     -1888041.3933000006,
#                     1196451.6270000003
#                 ],
#                 [
#                     -1887956.9909000006,
#                     1196383.9081999995
#                 ],
#                 [
#                     -1887898.7455000002,
#                     1196418.7337999996
#                 ],
#                 [
#                     -1887898.3966000006,
#                     1196423.1237000003
#                 ],
#                 [
#                     -1887896.7449999992,
#                     1196424.2434
#                 ],
#                 [
#                     -1887890.8530000001,
#                     1196499.8620999996
#                 ],
#                 [
#                     -1887966.7687999997,
#                     1196651.4004999995
#                 ],
#                 [
#                     -1887962.9791,
#                     1196688.8918999992
#                 ],
#                 [
#                     -1887874.929300001,
#                     1196748.3309000004
#                 ],
#                 [
#                     -1887872.3140999991,
#                     1196753.5791999996
#                 ],
#                 [
#                     -1887834.7895999998,
#                     1196830.9780000001
#                 ],
#                 [
#                     -1887788.5878999997,
#                     1196852.2983
#                 ],
#                 [
#                     -1887761.4288999997,
#                     1196835.5343999993
#                 ],
#                 [
#                     -1887735.7065999992,
#                     1196758.9713000003
# ...
#                     -1886499.6590999998,
#                     1195363.8414999992
#                 ],
#                 [
#                     -1886531.0884000007,
#                     1195338.2127
#                 ],
#                 [
#                     -1886564.4549000002,
#                     1195278.8912000004
#                 ],
#                 [
#                     -1886536.6656999998,
#                     1195236.5305000003
#                 ],
#                 [
#                     -1886543.5978999995,
#                     1195212.5898000002
#                 ],
#                 [
#                     -1886732.0176,
#                     1194922.9617999997
#                 ],
#                 [
#                     -1886775.4255,
#                     1194883.7026000004
#                 ],
#                 [
#                     -1886788.8421999998,
#                     1194810.2720999997
#                 ],
#                 [
#                     -1886769.0241999999,
#                     1194795.6502999999
#                 ],
#                 [
#                     -1886739.888699999,
#                     1194813.1129
#                 ],
#                 [
#                     -1886720.9777000006,
#                     1194850.6835999992
#                 ],
#                 [
#                     -1886677.5045999996,
#                     1194889.8171999995
#                 ],
#                 [
#                     -1886553.7224000003,
#                     1195095.1105000004
#                 ],
#                 [
#                     -1886522.4250000007,
#                     1195120.2260999996
#                 ],
#                 [
#                     -1886450.8466999996,
#                     1195090.9363000002
#                 ],
#                 [
#                     -1886431.5280000009,
#                     1195102.4219000004
#                 ],
#                 [
#                     -1886474.7861000001,
#                     1195201.3441000003
#                 ],
#                 [
#                     -1886473.4397999998,
#                     1195261.167199999
#                 ],
#                 [
#                     -1886431.0054000001,
#                     1195351.9799000006
#                 ],
#                 [
#                     -1886392.1446000002,
#                     1195375.4415000007
#                 ],
#                 [
#                     -1886326.1257000007,
#                     1195382.1366000008
#                 ],
#                 [
#                     -1886087.1051000003,
#                     1195295.1316999998
#                 ],
#                 [
#                     -1885890.6457000002,
#                     1195254.7972
#                 ],
#                 [
#                     -1885752.7737000007,
#                     1195205.6005000006
#                 ],
#                 [
#                     -1885589.2423999999,
#                     1195244.4891
#                 ],
#                 [
#                     -1885447.2313,
#                     1195237.1722999997
#                 ],
#                 [
#                     -1885353.5161000006,
#                     1195201.5248000007
#                 ],
#                 [
#                     -1885282.4781,
#                     1195197.8030999992
#                 ],
#                 [
#                     -1885172.6446000002,
#                     1195217.6664000005
#                 ],
#                 [
#                     -1885150.4417000003,
#                     1195211.1866999995
#                 ],
#                 [
#                     -1885100.2930999994,
#                     1195135.6654000003
#                 ],
#                 [
#                     -1885036.5284000002,
#                     1195134.7262999993
#                 ],
#                 [
#                     -1884883.3540000003,
#                     1195193.2059000004
#                 ],
#                 [
#                     -1884728.7995999996,
#                     1195174.0441999994
#                 ],
#                 [
#                     -1884534.0980999991,
#                     1195099.9584999997
#                 ],
#                 [
#                     -1884205.1294,
#                     1194909.2086999994
#                 ],
#                 [
#                     -1884110.0381000005,
#                     1194795.1502
#                 ],
#                 [
#                     -1883975.9033000004,
#                     1194677.9726999998
#                 ],
#                 [
#                     -1883882.6329999994,
#                     1194530.2989000008
#                 ],
#                 [
#                     -1883906.1834999993,
#                     1194476.9552999996
#                 ],
#                 [
#                     -1884018.8078000005,
#                     1194475.0408999994
#                 ],
#                 [
#                     -1884047.9429000001,
#                     1194457.5812999997
#                 ],
#                 [
#                     -1883988.3554999996,
#                     1194276.6513
#                 ],
#                 [
#                     -1883952.7303,
#                     1194206.0319999997
#                 ],
#                 [
#                     -1883824.4563999996,
#                     1194151.3355999999
#                 ],
#                 [
#                     -1883775.5960000008,
#                     1194154.1922999993
#                 ]
#             ],
#             [
#                 [
#                     -1883730.3323,
#                     1196020.0089999996
#                 ],
#                 [
#                     -1883686.5172000006,
#                     1196033.1778999995
#                 ],
#                 [
#                     -1883599.7071000002,
#                     1196249.2533999998
#                 ],
#                 [
#                     -1883434.1696000006,
#                     1196571.4967
#                 ],
#                 [
#                     -1883275.9145,
#                     1196757.7587000001
#                 ],
#                 [
#                     -1883157.3938999996,
#                     1196835.292199999
#                 ],
#                 [
#                     -1883150.4612000007,
#                     1196859.2323000003
#                 ],
#                 [
#                     -1883200.2688999996,
#                     1196908.0332999993
#                 ],
#                 [
#                     -1883220.4934999999,
#                     1196948.7434999999
#                 ],
#                 [
#                     -1883254.6811999995,
#                     1197079.1626999993
#                 ],
#                 [
#                     -1883284.2239999995,
#                     1197087.7892000005
#                 ],
#                 [
#                     -1883330.2664,
#                     1197067.0931000002
#                 ],
#                 [
#                     -1883385.6533000004,
#                     1197014.2105999999
#                 ],
#                 [
#                     -1883451.1725999992,
#                     1196981.4151000008
#                 ],
#                 [
#                     -1883559.0933999997,
#                     1196995.9127999991
#                 ],
#                 [
#                     -1883585.7519000005,
#                     1196986.5744000003
#                 ],
#                 [
#                     -1883638.3461000007,
#                     1196915.7498000003
#                 ],
#                 [
#                     -1883661.489,
#                     1196836.321799999
#                 ],
#                 [
#                     -1883682.819599999,
#                     1196652.5072000008
#                 ],
#                 [
#                     -1883667.1359,
#                     1196458.4342
#                 ],
#                 [
#                     -1883684.6020999998,
#                     1196343.0995000005
#                 ],
#                 [
#                     -1883745.0691999998,
#                     1196162.4251000006
#                 ],
#                 [
#                     -1883730.3323,
#                     1196020.0089999996
#                 ]
#             ],
#             [
#                 [
#                     -1884522.9362000003,
#                     1195855.2233000007
#                 ],
#                 [
#                     -1884505.7794000003,
#                     1195859.054300001
#                 ],
#                 [
#                     -1884496.5933999997,
#                     1195890.6250999998
#                 ],
#                 [
#                     -1884514.5647,
#                     1195938.9647000004
#                 ],
#                 [
#                     -1884468.4959999993,
#                     1195959.7652000003
#                 ],
#                 [
#                     -1884476.7422000002,
#                     1196014.103599999
#                 ],
#                 [
#                     -1884401.1305999998,
#                     1196026.2788999993
#                 ],
#                 [
#                     -1884377.0677000005,
#                     1196053.9475999996
#                 ],
#                 [
#                     -1884432.3944000006,
#                     1196139.2679999992
#                 ],
#                 [
#                     -1884453.1587000005,
#                     1196205.5491000004
#                 ],
#                 [
#                     -1884444.3800000008,
#                     1196263.205
#                 ],
#                 [
#                     -1884412.5434000008,
#                     1196262.7460999992
#                 ],
#                 [
#                     -1884394.9792,
#                     1196240.4920000006
#                 ],
#                 [
#                     -1884375.5689000003,
#                     1196251.9532999992
#                 ],
#                 [
#                     -1884392.6923999991,
#                     1196386.2241999991
#                 ],
#                 [
#                     -1884438.3608999997,
#                     1196476.9042000007
#                 ],
#                 [
#                     -1884467.9038999993,
#                     1196485.5293000005
#                 ],
#                 [
#                     -1884511.8109000009,
#                     1196472.3815000001
#                 ],
#                 [
#                     -1884552.1763000004,
#                     1196415.7774999999
#                 ],
#                 [
#                     -1884562.4337000009,
#                     1196297.7850000001
#                 ],
#                 [
#                     -1884602.6415999997,
#                     1196214.5024999995
#                 ],
#                 [
#                     -1884619.7914000005,
#                     1196073.1053
#                 ],
#                 [
#                     -1884619.2924000006,
#                     1196046.9974000007
#                 ],
#                 [
#                     -1884542.6621000003,
#                     1195869.8244000003
#                 ],
#                 [
#                     -1884522.9362000003,
#                     1195855.2233000007
#                 ]
#             ],
#             [
#                 [
#                     -1888419.6347000003,
#                     1195234.5803999994
#                 ],
#                 [
#                     -1888333.8879000004,
#                     1195226.6838000007
#                 ],
#                 [
#                     -1888272.9549000002,
#                     1195243.1587000005
#                 ],
#                 [
#                     -1888156.5298999995,
#                     1195312.9360000007
#                 ],
#                 [
#                     -1888179.0501000006,
#                     1195345.4744000006
#                 ],
#                 [
#                     -1888280.1741000004,
#                     1195383.3780000005
#                 ],
#                 [
#                     -1888302.7860000003,
#                     1195415.9388999995
#                 ],
#                 [
#                     -1888376.6459,
#                     1195437.4889000002
#                 ],
#                 [
#                     -1888395.9648000002,
#                     1195426.0018000007
#                 ],
#                 [
#                     -1888397.5335000008,
#                     1195365.6889999993
#                 ],
#                 [
#                     -1888432.6268000007,
#                     1195272.7305999994
#                 ],
#                 [
#                     -1888419.6347000003,
#                     1195234.5803999994
#                 ]
#             ],
#             [
#                 [
#                     -1883774.1502,
#                     1196420.7378000002
#                 ],
#                 [
#                     -1883754.857999999,
#                     1196432.1187999994
#                 ],
#                 [
#                     -1883798.114,
#                     1196531.0469000004
#                 ],
#                 [
#                     -1883828.0640999991,
#                     1196565.7580999993
#                 ],
#                 [
#                     -1883951.1635999996,
#                     1196610.6524
#                 ],
#                 [
#                     -1883985.2535999995,
#                     1196603.4814
#                 ],
#                 [
#                     -1883994.5715999994,
#                     1196571.3976000007
#                 ],
#                 [
#                     -1883972.0528999995,
#                     1196538.8544999994
#                 ],
#                 [
#                     -1883833.1440999992,
#                     1196437.9670000002
#                 ],
#                 [
#                     -1883774.1502,
#                     1196420.7378000002
#                 ]
#             ],
#             [
#                 [
#                     -1884870.8811000008,
#                     1195594.6239
#                 ],
#                 [
#                     -1884831.6393,
#                     1195591.8954000007
#                 ],
#                 [
#                     -1884768.4137999993,
#                     1195616.5278999992
#                 ],
#                 [
#                     -1884738.8709999993,
#                     1195607.9028999992
#                 ],
#                 [
#                     -1884700.6411000006,
#                     1195656.9569000006
#                 ],
#                 [
#                     -1884737.5238000005,
#                     1195667.7265000008
#                 ],
#                 [
#                     -1884740.7238999996,
#                     1195711.7535999995
#                 ],
#                 [
#                     -1884763.3341000006,
#                     1195744.3188000005
#                 ],
#                 [
#                     -1884820.9741999991,
#                     1195683.8030999992
#                 ],
#                 [
#                     -1884876.7419000007,
#                     1195657.1056999993
#                 ],
#                 [
#                     -1884886.0598000009,
#                     1195625.0216000006
#                 ],
#                 [
#                     -1884870.8811000008,
#                     1195594.6239
#                 ]
#             ],
#             [
#                 [
#                     -1885196.4754000008,
#                     1194336.1609000005
#                 ],
#                 [
#                     -1885167.3399999999,
#                     1194353.6217
#                 ],
#                 [
#                     -1885167.7473000009,
#                     1194379.7073
#                 ],
#                 [
#                     -1885221.3184999991,
#                     1194498.7657999992
#                 ],
#                 [
#                     -1885255.9071999993,
#                     1194517.7016000003
#                 ],
#                 [
#                     -1885284.9509999994,
#                     1194500.2180000003
#                 ],
#                 [
#                     -1885291.4762999993,
#                     1194450.1918000001
#                 ],
#                 [
#                     -1885218.5864000004,
#                     1194342.6182000004
#                 ],
#                 [
#                     -1885196.4754000008,
#                     1194336.1609000005
#                 ]
#             ]
#         ]
#     }
# }

# %%
# print attributes to check what are important features we can use to get the smoke estimate.
wf_feature['attributes']
# Out:
# {'OBJECTID': 1,
#  'USGS_Assigned_ID': 1,
#  'Assigned_Fire_Type': 'Wildfire',
#  'Fire_Year': 1860,
#  'Fire_Polygon_Tier': 1,
#  'Fire_Attribute_Tiers': '1 (1)',
#  'GIS_Acres': 3940.20708940724,
#  'GIS_Hectares': 1594.5452365353703,
#  'Source_Datasets': 'Comb_National_NIFC_Interagency_Fire_Perimeter_History (1)',
#  'Listed_Fire_Types': 'Wildfire (1)',
#  'Listed_Fire_Names': 'Big Quilcene River (1)',
#  'Listed_Fire_Codes': 'No code provided (1)',
#  'Listed_Fire_IDs': '',
#  'Listed_Fire_IRWIN_IDs': '',
#  'Listed_Fire_Dates': 'Listed Other Fire Date(s): 2006-11-02 - NIFC DATE_CUR field (1)',
#  'Listed_Fire_Causes': '',
#  'Listed_Fire_Cause_Class': 'Undetermined (1)',
#  'Listed_Rx_Reported_Acres': None,
#  'Listed_Map_Digitize_Methods': 'Other (1)',
#  'Listed_Notes': '',
#  'Processing_Notes': '',
#  'Wildfire_Notice': 'Wildfire mapping prior to 1984 was inconsistent, infrequent, and done without the aid of more modern fire mapping methods (GPS and satellite imagery). Areas burned prior to 1984 in this dataset represent only a fraction of what actually burned. While areas burned on or after 1984 are much more accurate and complete, errors still can and do occur. This dataset represents the most complete set of digitized polygon fire data available to the public that we, the authors, were able to collect. It is not a complete collection of all wildfires burned during the time period it represents.',
#  'Prescribed_Burn_Notice': 'Prescribed fire data in this dataset represents only a fraction of the area burned in prescribed burns across all years due to lack of reporting, particularly on private lands. The missing prescribed burn data becomes more pronounced further back in time, particularly in the southeastern U.S.; however, errors and omissions still occur through the most recent years in this dataset. This dataset represents the most complete set of digitized polygon fire data available to the public that we, the authors, were able to collect. It is not a complete collection of all prescribed burns burned during the time period it represents.',
#  'Wildfire_and_Rx_Flag': None,
#  'Overlap_Within_1_or_2_Flag': None,
#  'Circleness_Scale': 0.04758958417643999,
#  'Circle_Flag': None,
#  'Exclude_From_Summary_Rasters': 'No',
#  'Shape_Length': 64888.449849380544,
#  'Shape_Area': 15945452.365353702}

# %% [markdown]
# It seems like the data does not include exact date so it is difficult to filter for annual fire season but we can use the AQI API to filter for the annual fire season.

# %%
#
#    Every feature has a 'geometry' which specifies geo coordinates that make up each geographic thing
#    In the case of the wildfire data, most wildfires are bounded shapes, circles, squares, etc. This is
#    represented by shapes called 'rings' in GeoJSON.
# 
# Get the geometry for the feature we pulled from the feature_list
wf_geometry = wf_feature['geometry']
# The largest shape (ring) is supposed to be item zero in the list of 'rings'
wf_bigest_ring = wf_geometry['rings'][0]

print(f"The largest ring consists of {len(wf_bigest_ring)} points.")
# Out:
# The largest ring consists of 768 points.

# %% [markdown]
# ### Step 1: Create fire smoke estimates
#
# As part of part 1 - Common analysis I need to find annual estimate of smoke seen by Alexandria, VA during the fire season.
#
# Smoke estimate should adhere to the following conditions:
#
# -   The estimate only considers the last 60 years of wildland fire data (1961-2021).
# -   The estimate only considers fires that are within 650 miles of your assigned city.
# -   Defines the annual fire season as running from May 1st through October 31st.
#
# The code below uses multithreading which is an approach to run the processes parallely. I have referenced this code from my classmates by collaborating with them. My intital approach was to use a single core for processing which also generates the same result. I have added that code block below to reproduce if there are limitations on running the code on multiple cores.
#
# Note: The code takes about 30-40 minutes to run on multiple cores and 112 minutes to run on single core.

# %%
# setting up constants to create the two dataframes for shortest distance and avg distance of fire from the place
place = CITY_LOCATIONS["Alexandria"]
fire_info = {}
fire_errors = {}

# %% [markdown]
# The code below uses multiprocessing to speed up the process to get the fire distances and parse the data. To process the fire information I have created a module called compute_distance which we import below. the function 'process_fire_feature' processes individual fires but because the program runs on multiple cores the time for distance compuation is reduced significantly. This code was developed by collaborating with my classmates.
#
# Note: Running this below cell can take about 70-100 minutes depending on how many cores are used to run the program.

# %%
# %%time
# below code can run the code on multithreading and generate a fire_info dataframe 
# which has a key name year-unique_id-fire_name and value is the dictionary which holds the distance information for that fire.


# Create a multiprocessing pool
pool = multiprocessing.Pool(4) # change the number of cores here

# Prepare input data for the pool
input_data = [(wf_feature, place, i) for i, wf_feature in enumerate(feature_list)]

# Process the fire features in parallel
results = pool.starmap(process_fire_feature, input_data)

# Close the pool and wait for all processes to finish
pool.close()
pool.join()

# Process the results
for result in results:
    key, fire = result
    if isinstance(fire, dict):
        fire_info[key] = fire
    else:
        fire_errors[key] = fire
# Out:
# Error in processing the wildfire data for MICHAEL CROWE (1) from 2010. (Key - 2010-114308-MICHAEL CROWE (1)
# 0
# Error in processing the wildfire data for JEANETTE WALKER (1) from 2010. (Key - 2010-114321-JEANETTE WALKER (1)
# 0
# Error in processing the wildfire data for BOYD JOHNSON (1) from 2007. (Key - 2007-110223-BOYD JOHNSON (1)
# 0
# Error in processing the wildfire data for VIRGINIAS (3) from 2008. (Key - 2008-110638-VIRGINIAS (3)
# 0
# Error in processing the wildfire data for NORTH DIVIDE UNIT 12 (2) from 2020. (Key - 2020-127491-NORTH DIVIDE UNIT 12 (2)
# 0
# Error in processing the wildfire data for MYRTLE BB WUI FY 15 (1) from 2015. (Key - 2015-119581-MYRTLE BB WUI FY 15 (1)
# 0
# Error in processing the wildfire data for RICHARDS from 2015. (Key - 2015-119616-RICHARDS
# 0
# Error in processing the wildfire data for DELTA BLOCK 1 (1) from 2015. (Key - 2015-119750-DELTA BLOCK 1 (1)
# 0
# Error in processing the wildfire data for No Fire Name Provided (2) from 2012. (Key - 2012-115628-No Fire Name Provided (2)
# 0
# Error in processing the wildfire data for GEORGE BRAND (1) from 2008. (Key - 2008-111430-GEORGE BRAND (1)
# 0
# Error in processing the wildfire data for JIM BETHEL GFC (1) from 2015. (Key - 2015-119981-JIM BETHEL GFC (1)
# 0
# Error in processing the wildfire data for No Fire Name Provided (1) from 2012. (Key - 2012-115973-No Fire Name Provided (1)
# 0
# Error in processing the wildfire data for INTERDISCIPLINARY UNIT LBJ 41 - PATCH BURN UNIT A (HOPWELL CHURCH) (1) from 2015. (Key - 2015-120211-INTERDISCIPLINARY UNIT LBJ 41 - PATCH BURN UNIT A (HOPWELL CHURCH) (1)
# 0
# Error in processing the wildfire data for VIRGINIAS (2) from 2009. (Key - 2009-111896-VIRGINIAS (2)
# 0
# Error in processing the wildfire data for Little Bald Hills - Williams Ridge Rx (2) from 2012. (Key - 2012-116234-Little Bald Hills - Williams Ridge Rx (2)
# 0
# Error in processing the wildfire data for FULTON (1) from 2016. (Key - 2016-120677-FULTON (1)
# 0
# Error in processing the wildfire data for JAMIE JORDON (1) from 2009. (Key - 2009-112409-JAMIE JORDON (1)
# 0
# Error in processing the wildfire data for JIM TIMBERLAKE (1) from 2009. (Key - 2009-112414-JIM TIMBERLAKE (1)
# 0
# Error in processing the wildfire data for No Fire Name Provided (1) from 2016. (Key - 2016-121009-No Fire Name Provided (1)
# 0
# Error in processing the wildfire data for BALANCE UNDERBURN UNIT 2-1 (1) from 2013. (Key - 2013-117085-BALANCE UNDERBURN UNIT 2-1 (1)
# 0
# Error in processing the wildfire data for BJUGSTAD/OWEGO ANNEX - BJUGSTAD WEST SPRING BURN 2019 (1) from 2019. (Key - 2019-125744-BJUGSTAD/OWEGO ANNEX - BJUGSTAD WEST SPRING BURN 2019 (1)
# 0
# Error in processing the wildfire data for No Fire Name Provided (1) from 2010. (Key - 2010-113410-No Fire Name Provided (1)
# 0
# Error in processing the wildfire data for WILLIAM GHOLSTON (1) from 2010. (Key - 2010-113664-WILLIAM GHOLSTON (1)
# 0
# Error in processing the wildfire data for JOHN HUTCHESON (1) from 2010. (Key - 2010-113737-JOHN HUTCHESON (1)
# 0
# Error in processing the wildfire data for JEAN DODSON (1) from 2010. (Key - 2010-113765-JEAN DODSON (1)
# 0
# Error in processing the wildfire data for KEITH O'DANIEL (1) from 2010. (Key - 2010-113804-KEITH O'DANIEL (1)
# 0
# Error in processing the wildfire data for LITTLE SPRINGS - LITTLE SPRINGS  BROADCAST BURN (1) from 2017. (Key - 2017-122263-LITTLE SPRINGS - LITTLE SPRINGS  BROADCAST BURN (1)
# 0
# Error in processing the wildfire data for BARNES SOUTH UNDERBURN - BARNES SOUTH  UNDERBURN (1) from 2007. (Key - 2007-109604-BARNES SOUTH UNDERBURN - BARNES SOUTH  UNDERBURN (1)
# 0
# Error in processing the wildfire data for BOYD JOHNSON (1) from 2007. (Key - 2007-110223-BOYD JOHNSON (1)
# 0
# Error in processing the wildfire data for VIRGINIAS (3) from 2008. (Key - 2008-110638-VIRGINIAS (3)
# 0
# Error in processing the wildfire data for GEORGE BRAND (1) from 2008. (Key - 2008-111430-GEORGE BRAND (1)
# 0
# Error in processing the wildfire data for NORTH DIVIDE UNIT 12 (2) from 2020. (Key - 2020-127491-NORTH DIVIDE UNIT 12 (2)
# 0
# Error in processing the wildfire data for VIRGINIAS (2) from 2009. (Key - 2009-111896-VIRGINIAS (2)
# 0
# Error in processing the wildfire data for MYRTLE BB WUI FY 15 (1) from 2015. (Key - 2015-119581-MYRTLE BB WUI FY 15 (1)
# 0
# Error in processing the wildfire data for RICHARDS from 2015. (Key - 2015-119616-RICHARDS
# 0
# Error in processing the wildfire data for JAMIE JORDON (1) from 2009. (Key - 2009-112409-JAMIE JORDON (1)
# 0
# Error in processing the wildfire data for JIM TIMBERLAKE (1) from 2009. (Key - 2009-112414-JIM TIMBERLAKE (1)
# 0
# Error in processing the wildfire data for DELTA BLOCK 1 (1) from 2015. (Key - 2015-119750-DELTA BLOCK 1 (1)
# 0
# Error in processing the wildfire data for JIM BETHEL GFC (1) from 2015. (Key - 2015-119981-JIM BETHEL GFC (1)
# 0
# Error in processing the wildfire data for INTERDISCIPLINARY UNIT LBJ 41 - PATCH BURN UNIT A (HOPWELL CHURCH) (1) from 2015. (Key - 2015-120211-INTERDISCIPLINARY UNIT LBJ 41 - PATCH BURN UNIT A (HOPWELL CHURCH) (1)
# 0
# Error in processing the wildfire data for FULTON (1) from 2016. (Key - 2016-120677-FULTON (1)
# 0
# Error in processing the wildfire data for No Fire Name Provided (1) from 2010. (Key - 2010-113410-No Fire Name Provided (1)
# 0
# Error in processing the wildfire data for WILLIAM GHOLSTON (1) from 2010. (Key - 2010-113664-WILLIAM GHOLSTON (1)
# 0
# Error in processing the wildfire data for No Fire Name Provided (1) from 2016. (Key - 2016-121009-No Fire Name Provided (1)
# 0
# Error in processing the wildfire data for JOHN HUTCHESON (1) from 2010. (Key - 2010-113737-JOHN HUTCHESON (1)
# 0
# Error in processing the wildfire data for JEAN DODSON (1) from 2010. (Key - 2010-113765-JEAN DODSON (1)
# 0
# Error in processing the wildfire data for KEITH O'DANIEL (1) from 2010. (Key - 2010-113804-KEITH O'DANIEL (1)
# 0
# Error in processing the wildfire data for MICHAEL CROWE (1) from 2010. (Key - 2010-114308-MICHAEL CROWE (1)
# 0
# Error in processing the wildfire data for JEANETTE WALKER (1) from 2010. (Key - 2010-114321-JEANETTE WALKER (1)
# 0
# Error in processing the wildfire data for LITTLE SPRINGS - LITTLE SPRINGS  BROADCAST BURN (1) from 2017. (Key - 2017-122263-LITTLE SPRINGS - LITTLE SPRINGS  BROADCAST BURN (1)
# 0
# Error in processing the wildfire data for No Fire Name Provided (2) from 2012. (Key - 2012-115628-No Fire Name Provided (2)
# 0
# Error in processing the wildfire data for No Fire Name Provided (1) from 2012. (Key - 2012-115973-No Fire Name Provided (1)
# 0
# Error in processing the wildfire data for Little Bald Hills - Williams Ridge Rx (2) from 2012. (Key - 2012-116234-Little Bald Hills - Williams Ridge Rx (2)
# 0
# Error in processing the wildfire data for BALANCE UNDERBURN UNIT 2-1 (1) from 2013. (Key - 2013-117085-BALANCE UNDERBURN UNIT 2-1 (1)
# 0
# Error in processing the wildfire data for BARNES SOUTH UNDERBURN - BARNES SOUTH  UNDERBURN (1) from 2007. (Key - 2007-109604-BARNES SOUTH UNDERBURN - BARNES SOUTH  UNDERBURN (1)
# 0
# Error in processing the wildfire data for BJUGSTAD/OWEGO ANNEX - BJUGSTAD WEST SPRING BURN 2019 (1) from 2019. (Key - 2019-125744-BJUGSTAD/OWEGO ANNEX - BJUGSTAD WEST SPRING BURN 2019 (1)
# 0
# CPU times: user 46.7 s, sys: 47.2 s, total: 1min 33s
# Wall time: 2h 27min 37s

# %%
# years for which we have valid fire information

unique_years = {key.split('-')[0] for key in fire_info.keys()}

print("Information for fire avaliable for the following years: ", unique_years)

# years for which the fire information has errors

unique_error_years = {key.split('-')[0] for key in fire_errors.keys()}

print("Information for fire which has error for the following years: ", unique_error_years)
# Out:
# Information for fire avaliable for the following years:  {'1953', '1940', '1997', '1963', '2004', '1998', '1972', '1937', '1899', '1979', '1881', '1933', '1870', '1893', '1970', '1971', '1999', '1995', '1985', '1911', '1962', '1947', '1994', '1966', '1903', '1859', '1914', '1901', '2015', '1929', '1949', '1951', '1978', '2008', '2019', '1965', '2020', '1931', '1916', '1939', '1898', '1992', '1923', '2013', '1993', '2003', '1960', '1890', '1986', '1954', '1988', '1922', '1907', '1915', '1891', '1958', '1934', '1943', '2006', '1902', '1957', '1961', '1982', '1906', '1990', '1905', '1900', '1938', '1981', '1967', '1872', '1912', '1955', '1878', '2001', '1888', '1973', '2014', '1946', '2011', '1952', '1935', '1974', '1920', '1996', '1964', '1936', '1977', '1880', '1889', '1932', '1980', '1918', '1876', '1991', '1987', '2010', '1930', '1968', '1927', '2007', '1945', '1925', '1924', '1885', '1976', '1926', '1956', '1895', '1908', '1983', '1894', '1919', '2017', '2016', '1941', '1921', '1969', '1892', '2012', '1928', '1913', '1909', '1959', '1989', '2009', '2005', '1877', '1886', '1910', '1904', '2018', '1835', '1948', '1942', '1950', '1896', '2002', '1944', '2000', '1984', '1860', '1975', '1917'}
# Information for fire which has error for the following years:  {'2009', '2020', '2007', '2012', '2015', '2017', '2008', '2019', '2010', '2013', '2016'}

# %%
# save intermediary files to prevent running the code again and can be used for analysis

# Define the directory path
directory = '../intermediary_files'

# Check if the directory exists, and create it if not
if not os.path.exists(directory):
    os.mkdir(directory)

# Define file paths within the directory
fire_dist_info_file = os.path.join(directory, 'fire_dist_info.csv')
fire_error_file = os.path.join(directory, 'fire_error_info.csv')

fire_info_df = pd.DataFrame(fire_info)
fire_errors_df = pd.DataFrame(fire_errors)

# Transpose the dataframe to have fire names as rows and features as columns
fire_info_transposed_df = fire_info_df.T

# Display the first few rows of the transposed dataframe to verify structure
fire_info_transposed_df.head()

# Split 'distance_shortest' into 'shortest_distance' and 'shortest_latlon'
fire_info_transposed_df['shortest_distance'] = fire_info_transposed_df['distance_shortest'].apply(lambda x: x[0])
fire_info_transposed_df['shortest_latlon'] = fire_info_transposed_df['distance_shortest'].apply(lambda x: x[1])

# Drop the original 'distance_shortest' column if no longer needed
fire_info_transposed_df.drop(columns=['distance_shortest'], inplace=True)
fire_info_transposed_df.head()

# Save each DataFrame to a CSV file in the specified directory
fire_info_transposed_df.to_csv(fire_dist_info_file, index=True)
fire_errors_df.to_csv(fire_error_file, index=True)

print("Results saved to CSV files in the 'intermediary_files' folder.")
# Out:
# Results saved to CSV files in the 'intermediary_files' folder.

# %%
# Load and convert JSON files to DataFrames
fire_info_df = pd.read_csv(fire_dist_info_file)
fire_errors_df = pd.read_csv(fire_error_file)

# %%
fire_info_df.head()
# Out:
#                          Unnamed: 0  year                       name  \
# 0     1860-0-Big Quilcene River (1)  1860     Big Quilcene River (1)
# 1          1860-1-Harrison Lake (1)  1860          Harrison Lake (1)
# 2           1860-2-Tunnel Creek (1)  1860           Tunnel Creek (1)
# 3                   1870-3-1870 (2)  1870                   1870 (2)
# 4  1870-4-No Fire Name Provided (2)  1870  No Fire Name Provided (2)
#
#            size      type  circleness_scale  avg_distance  \
# 0   3940.207089  Wildfire          0.047590   2363.599988
# 1    772.518249  Wildfire          0.071367   2363.343057
# 2    333.020409  Wildfire          0.379578   2364.539010
# 3  22294.993577  Wildfire          0.158038   2018.921232
# 4     36.985574  Wildfire          0.218009   1950.104161
#
#                              perimeter_start  shortest_distance  \
# 0   (47.82096426863667, -123.03391282044802)        2361.346757
# 1  (47.760085709530074, -123.05860885146123)        2362.275225
# 2   (47.77931119606787, -123.09626737568851)        2364.053410
# 3   (46.05639337297983, -115.76193511192794)        2016.893685
# 4   (43.92219609043536, -114.27933395410464)        1950.004772
#
#                             shortest_latlon
# 0  (47.84027067710627, -123.02441580365677)
# 1   (47.76115537575925, -123.0400768984296)
# 2  (47.78673744181255, -123.07971349587145)
# 3  (46.00960219130561, -115.70398557512712)
# 4  (43.92446198091773, -114.27909408546735)

# %%
fire_info_df['type'].value_counts()
# Out:
# type
# Wildfire                            86218
# Prescribed Fire                     33294
# Likely Wildfire                     11666
# Unknown - Likely Prescribed Fire     3291
# Unknown - Likely Wildfire             564
# Name: count, dtype: int64

# %% [markdown]
# We can encode the fire type to get impact of the fire on the smoke estimate. The fire of type wildfire should have more iimpact compared to a prescribed one as it should ideally be in control.

# %%
# Example encoding dictionary
fire_type_encoding = {
    "Wildfire": 5,
    "Likely Wildfire": 4,
    "Unknown - Likely Wildfire": 3, 
    "Prescribed Fire": 2, # lower impact
    "Unknown - Likely Prescribed Fire": 1 # lower impact
}

# Assuming `df` is your DataFrame with a column 'fire_type'
fire_info_df['fire_type_encoded'] = fire_info_df['type'].map(fire_type_encoding)

# %% [markdown]
# Below errors csv contains the fire for which we got an error.

# %%
fire_errors_df.head()
# Out:
#                                           Unnamed: 0  0
# 0  2007-109604-BARNES SOUTH UNDERBURN - BARNES SO...  0
# 1                       2007-110223-BOYD JOHNSON (1)  0
# 2                          2008-110638-VIRGINIAS (3)  0
# 3                       2008-111430-GEORGE BRAND (1)  0
# 4                          2009-111896-VIRGINIAS (2)  0

# %% [markdown]
# ### Step 2: Developing smoke estimates
#
# Assumptions:
#
# - Linear Decay of Impact by Distance: We assume that the smoke effect decreases linearly with distance.
# - Direct Proportionality to Fire Size: Larger fires produce more smoke, which affects the air quality more.
# - Cumulative Annual Smoke: A cumulative smoke effect for each year is initially used to give an aggregate yearly smoke estimate for simplicity.
# - Circleness_scale is used to represent the intensity of the fire with reference to [this](https://wfca.com/wildfire-articles/fire-intensity-an-in-depth-guide/)
#
# First we apply the conditions specified for the fire for distance and year. As seen in one of the above cell where we look at the attributes of the fire there is no date information so it is difficult to filter for the annual fire season.

# %%
# Define constants
START_YEAR = 1961
END_YEAR = 2021
DISTANCE_THRESHOLD = 650


# Filter fires within the last 60 years (1961-2021), within 650 miles, and within fire season
filtered_df = fire_info_df[
    (fire_info_df['year'] >= START_YEAR) & 
    (fire_info_df['year'] <= END_YEAR) & 
    (fire_info_df['shortest_distance'].apply(lambda x: x <= DISTANCE_THRESHOLD))
]

filtered_df.head()
# Out:
#                            Unnamed: 0  year                 name       size  \
# 13778  1961-13778-W_C_H_4_3_W1_61 (2)  1961  W_C_H_4_3_W1_61 (2)  28.693900
# 13792       1961-13792-FALL BRANC (2)  1961       FALL BRANC (2)  13.973044
# 13809       1961-13809-WORLEY KNO (2)  1961       WORLEY KNO (2)   6.655655
# 13810  1961-13810-CW_H_4_2_W12_61 (2)  1961  CW_H_4_2_W12_61 (2)   6.387265
# 13836        1961-13836-FOOTHILLS (2)  1961        FOOTHILLS (2)   1.527601
#
#            type  circleness_scale  avg_distance  \
# 13778  Wildfire          0.648984    426.356838
# 13792  Wildfire          0.580768    428.070862
# 13809  Wildfire          0.745906    420.876349
# 13810  Wildfire          0.761103    439.836810
# 13836  Wildfire          0.782713    435.545571
#
#                                 perimeter_start  shortest_distance  \
# 13778  (35.675731798257715, -83.71589029532807)         426.159008
# 13792  (35.658386536996765, -83.73666367421406)         427.994728
# 13809   (35.46030766855338, -83.41782178915307)         420.797336
# 13810    (35.60967334366376, -83.9442967311793)         439.793960
# 13836  (35.670698246564235, -83.90266194869604)         435.501251
#
#                                 shortest_latlon  fire_type_encoded
# 13778   (35.67698964517509, -83.70966687469813)                  5
# 13792   (35.658889182769094, -83.7342160693799)                  5
# 13809  (35.460386527612144, -83.41673215456898)                  5
# 13810    (35.60967334366376, -83.9442967311793)                  5
# 13836  (35.671137177075195, -83.90149204817143)                  5

# %%
# Analysis to check the data
# Find fire with smallest and largest size
smallest_size_fire = filtered_df.loc[filtered_df['size'].idxmin()]
largest_size_fire = filtered_df.loc[filtered_df['size'].idxmax()]

# Find fire with shortest and largest shortest_distance
shortest_distance_fire = filtered_df.loc[filtered_df['shortest_distance'].idxmin()]
largest_distance_fire = filtered_df.loc[filtered_df['shortest_distance'].idxmax()]

# Display results
print("Fire with Smallest Size:")
print(smallest_size_fire, "\n")

print("Fire with Largest Size:")
print(largest_size_fire, "\n")

print("Fire with Shortest Distance:")
print(shortest_distance_fire, "\n")

print("Fire with Largest Distance:")
print(largest_distance_fire)
# Out:
# Fire with Smallest Size:
# Unnamed: 0                      2013-63532-RipRap AT Fire (2)
# year                                                     2013
# name                                       RipRap AT Fire (2)
# size                                                      0.0
# type                                                 Wildfire
# circleness_scale                                     0.902387
# avg_distance                                        102.68416
# perimeter_start       (38.18193696253812, -78.76194163424607)
# shortest_distance                                  102.684157
# shortest_latlon      (38.181936941502045, -78.76194159176997)
# fire_type_encoded                                           5
# Name: 63532, dtype: object
#
# Fire with Largest Size:
# Unnamed: 0                       2011-81894-HONEY PRAIRIE (2)
# year                                                     2011
# name                                        HONEY PRAIRIE (2)
# size                                            338877.715578
# type                                                 Wildfire
# circleness_scale                                     0.037932
# avg_distance                                       624.331067
# perimeter_start      (31.137771103492927, -82.06160419333034)
# shortest_distance                                  600.432942
# shortest_latlon       (31.14622505778958, -82.06595066350079)
# fire_type_encoded                                           5
# Name: 81894, dtype: object
#
# Fire with Shortest Distance:
# Unnamed: 0                           1988-29444-PASTURE 1 (3)
# year                                                     1988
# name                                            PASTURE 1 (3)
# size                                                 45.32225
# type                                                 Wildfire
# circleness_scale                                     0.612109
# avg_distance                                         2.496429
# perimeter_start       (38.80455430765781, -77.01191734899433)
# shortest_distance                                    2.263258
# shortest_latlon      (38.805513568214266, -77.01321270819548)
# fire_type_encoded                                           5
# Name: 29444, dtype: object
#
# Fire with Largest Distance:
# Unnamed: 0                         2007-53819-BIRD KIOSK (2)
# year                                                    2007
# name                                          BIRD KIOSK (2)
# size                                                2.583644
# type                                                Wildfire
# circleness_scale                                    0.163189
# avg_distance                                      650.006826
# perimeter_start      (34.28777420138369, -87.30763588403825)
# shortest_distance                                 649.978454
# shortest_latlon      (34.28854981042949, -87.30754037751275)
# fire_type_encoded                                          5
# Name: 53819, dtype: object

# %%
filtered_df[filtered_df['size'] == filtered_df['size'].min()]
# Out:
#                           Unnamed: 0  year                name          size  \
# 63532  2013-63532-RipRap AT Fire (2)  2013  RipRap AT Fire (2)  2.275346e-08
#
#            type  circleness_scale  avg_distance  \
# 63532  Wildfire          0.902387     102.68416
#
#                                perimeter_start  shortest_distance  \
# 63532  (38.18193696253812, -78.76194163424607)         102.684157
#
#                                 shortest_latlon  fire_type_encoded
# 63532  (38.181936941502045, -78.76194159176997)                  5

# %% [markdown]
# The above results show that the smallest fire size (GIS_Acres) is 2.275346e-08 which should ideally not be a part of the dataset as it is means the fire is basically non existant as the GIS acres is very small.

# %%
# Example threshold
threshold = 1e-6

# Filter the DataFrame
filtered_df = filtered_df[filtered_df['size'] > threshold]

# %%
# Calculate Smoke Estimate based on (Fire Size / Distance) * (circleness_score) * (encoded type of fire)

filtered_df['smoke_estimate'] = filtered_df.apply(
    lambda x: ((0.5 + x['circleness_scale'])/2) * (x['fire_type_encoded']) * (x['size']) * (1 / x['shortest_distance']),
    axis=1
)
filtered_df.to_csv("../intermediary_files/smoke_estimates.csv")
# Group by year to calculate cumulative smoke for each year
annual_smoke_estimate = filtered_df.groupby('year')['smoke_estimate'].mean()

print("Annual Smoke Estimate by Year:")
print(annual_smoke_estimate)
# Out:
# Annual Smoke Estimate by Year:
# year
# 1961     0.167383
# 1962     6.096890
# 1963     8.177903
# 1964     0.150089
# 1965     0.235114
# 1966     0.069257
# 1967     0.997449
# 1968     0.789350
# 1969     0.528641
# 1970     1.948496
# 1971     1.670289
# 1972     0.091170
# 1973     0.241034
# 1974     0.232841
# 1975     0.217733
# 1976     0.403352
# 1977     0.705933
# 1978     1.133789
# 1979     0.400432
# 1980     1.503642
# 1981     0.339768
# 1982     0.169309
# 1983     0.265882
# 1984     0.301352
# 1985     9.933734
# 1986     5.208134
# 1987    14.344790
# 1988     1.562067
# 1989     2.056334
# 1990     1.335250
# 1991    11.481725
# 1992     1.787157
# 1993     0.794031
# 1994     2.627775
# 1995     1.460549
# 1996     0.721129
# 1997     1.128573
# 1998     1.429996
# 1999     4.312745
# 2000     4.785781
# 2001     3.680451
# 2002     3.504561
# 2003     1.388726
# 2004     2.583652
# 2005     2.391969
# 2006     2.194324
# 2007     3.178286
# 2008     3.227927
# 2009     2.120966
# 2010     1.867397
# 2011     5.803643
# 2012     3.229545
# 2013     1.327063
# 2014     1.328153
# 2015     1.124637
# 2016     2.976508
# 2017     2.405600
# 2018     1.329499
# 2019     1.029110
# 2020     0.855885
# Name: smoke_estimate, dtype: float64

# %%
# Plot using pandas
annual_smoke_estimate.plot(kind='line', figsize=(10, 6), marker='o', title='Annual Smoke Estimate by Year')
plt.xlabel('Year')
plt.ylabel('Average Smoke Estimate')
plt.grid(True)
plt.show()

# %% [markdown]
# The maximum fire smoke was between the year 2015 to 2020 and over the following years the peaks are intermitent. With an overall increasing trend.

# %% [markdown]
# ### Step 3: Compare smoke estimates derieved with the AQI values received.

# %% [markdown]
# Next step is to understand how good or bad my smoke estimate might be. I will now compare my estimate to available AQI (Air Quality Index) data from the US EPA. The US EPA was only created in 1973, and did not really begin installing air quality monitoring stations until the early 1980s. Further, of 3000+ counties in the US, the EPA has vetted monitoring stations in only 2000 of them. This means that US EPA AQI measures for any one city will need to be some kind of estimate based on monitoring stations that are nearby.
#
# The final_AQI.csv is generated from the `epq_air_quality_history.ipynb` file. That file needs to be run first before running the below cells.

# %%
df_final_AQI = pd.read_csv('../intermediary_files/final_AQI.csv')
df_final_AQI.head()
# Out:
#    Unnamed: 0.1  Unnamed: 0  state_code  county_code  site_number  \
# 0             0           0          24            3         1003
# 1             1           1          24            3         1003
# 2             2           2          24            3         1003
# 3             3           3          24            3         1003
# 4             4           4          24            3         1003
#
#    parameter_code   latitude  longitude        parameter sample_duration  \
# 0           42101  39.169533 -76.627933  Carbon monoxide          1 HOUR
# 1           42101  39.169533 -76.627933  Carbon monoxide          1 HOUR
# 2           42101  39.169533 -76.627933  Carbon monoxide          1 HOUR
# 3           42101  39.169533 -76.627933  Carbon monoxide          1 HOUR
# 4           42101  39.169533 -76.627933  Carbon monoxide          1 HOUR
#
#    date_local   units_of_measure  arithmetic_mean  first_max_value       aqi
# 0  1968-05-02  Parts per million         3.250000              4.0  3.250000
# 1  1968-05-03  Parts per million         1.363636              3.0  1.363636
# 2  1968-05-06  Parts per million         1.750000              3.0  1.750000
# 3  1968-05-07  Parts per million         1.583333              6.0  1.583333
# 4  1968-05-08  Parts per million         1.000000              9.0  1.000000

# %%
# Ensure 'date' column is in datetime format
df_final_AQI['date_local'] = pd.to_datetime(df_final_AQI['date_local'])
df_final_AQI['year'] = df_final_AQI['date_local'].dt.year
# Group by year to calculate cumulative smoke for each year
annual_aqi = df_final_AQI.groupby('year')['aqi'].mean()

# Plot without setting date as index
plt.figure(figsize=(10, 6))
plt.plot(df_final_AQI['date_local'], df_final_AQI['aqi'])
plt.xlabel('Date')
plt.ylabel('Arithmetic Mean AQI')
plt.title('AQI Arithmetic Mean per day')
plt.xticks(rotation=45)  # Rotate date labels for better readability
plt.show()

# %%
annual_aqi.plot()
# Out:
# <Axes: xlabel='year'>

# %%
# Group by year to calculate annual averages
annual_aqi = df_final_AQI.groupby('year')['aqi'].mean()
annual_smoke_estimate = filtered_df.groupby('year')['smoke_estimate'].mean()

# Plotting both AQI over time and annual smoke estimate on the same plot
fig, ax1 = plt.subplots(figsize=(12, 6))

# Plot AQI on the primary y-axis
ax1.plot(annual_aqi.index, annual_aqi, marker = 'o', label='Annual AQI Over Time', color='blue')
ax1.set_xlabel('Year')
ax1.set_ylabel('AQI', color='blue')
ax1.tick_params(axis='y', labelcolor='blue')
ax1.set_title('AQI and Annual Smoke Estimate Over Time')
ax1.tick_params(axis='x', rotation=45)

# Use the secondary y-axis to plot the annual smoke estimate
ax2 = ax1.twinx()
ax2.plot(annual_smoke_estimate.index, annual_smoke_estimate, marker = '*', label='Annual Smoke Estimate', color='red')
ax2.set_ylabel('Smoke Estimate', color='orange')
ax2.tick_params(axis='y', labelcolor='orange')

# Add legends
ax1.legend(loc='upper left')
ax2.legend(loc='upper right')

plt.show()

# %%
# We can merge the two AQI and smoke estimate data to get the correlation, thus we merge on "Year", keeping all years from both DataFrames
df_annual_aqi = annual_aqi.to_frame(name='annual_aqi')
df_annual_smoke_estimate = annual_smoke_estimate.to_frame(name='annual_smoke_estimate')

merged_df = pd.merge(df_annual_aqi, df_annual_smoke_estimate, left_index=True, right_index=True)

# %%
correlation = merged_df[['annual_smoke_estimate', 'annual_aqi']].corr().iloc[0, 1]
print(f'Pearson correlation between Total annual smoke impact and Average annual AQI: {correlation}')
# Out:
# Pearson correlation between Total annual smoke impact and Average annual AQI: 0.3103403257898602

# %%
from statsmodels.tsa.arima.model import ARIMA
# from sklearn.metrics import mean_squared_error, mean_absolute_error

df = merged_df.reset_index()
df = df[['year', 'annual_smoke_estimate']]

# Split data into train and test sets
train_df = df[df['year'] < 2020]
test_df = df[df['year'] >= 2020]

# %%
# Forecasting for 2020-2050 with ARIMA and calculating uncertainty bounds
forecast_years = range(2020, 2051)
n_forecasts = len(forecast_years)
forecast_result = ARIMA(df['annual_smoke_estimate'], order=(2, 1, 1)).fit()
forecast = forecast_result.get_forecast(steps=n_forecasts)
print(forecast)
forecast_mean = forecast.predicted_mean
forecast_conf_int = forecast.conf_int(alpha=0.05)  # 95% confidence interval

# Plotting historical data and forecast with uncertainty bounds
plt.figure(figsize=(12, 6))
plt.plot(df['year'], df['annual_smoke_estimate'], label='Historical Data', color='blue')
plt.plot(forecast_years, forecast_mean, label='Forecast Mean', color='red')
plt.fill_between(forecast_years, forecast_conf_int.iloc[:, 0], forecast_conf_int.iloc[:, 1], color='pink', alpha=0.3, label='95% Confidence Interval')
plt.title("Forecast of smoke_estimate from 2020 to 2050 with Uncertainty Bounds")
plt.xlabel("Year")
plt.ylabel("annual_smoke_estimate")
plt.legend()
plt.show()
# Out:
# <statsmodels.tsa.statespace.mlemodel.PredictionResultsWrapper object at 0x4e4394920>
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/statsmodels/tsa/statespace/sarimax.py:966: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/statsmodels/tsa/statespace/sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'

# %% [markdown]
# Above model is forecasting the smoke estimate for Alexandria from 2021 to 2050 with a 95% confidence interval. I choose to use Arima model as it is a time series data. The resultant smoke estimate seems to stay constant over the period of time which does not seem realistic. In an ideal case the smoke estimates should be varying with other external factors which we have not incorporated in the analysis.

# %% [markdown]
# ### APPENDIX
# The commented code logic below is to compute distances of fire from Alexandria which runs on a single core.

# %%
# # below code will run on a single core - which takes about 112 minutes to complete and 
# # generate the two dataframes for shortest and avergare 
# # distance from the fire.

# from compute_distance import shortest_distance_from_place_to_fire_perimeter, average_distance_from_place_to_fire_perimeter, convert_ring_to_epsg4326

# json_structure = {'wild_fire_name': '', 'distance': None, 'size': None, 'latlon': (None, None), 'year': ''}
# json_structure_error = {'wild_fire_name': '', 'error': ''}

# shortest_dist_650_wf = {}
# shortest_error_wf = {}

# avg_dist_650_wf = {}
# avg_error_wf = {}

# for wf_feature in feature_list:
#     #print(f"{place['city']}")
#     wf_year = wf_feature['attributes']['Fire_Year']
#     wf_name = wf_feature['attributes']['Listed_Fire_Names'].split(',')[0]
#     wf_size = wf_feature['attributes']['GIS_Acres']
#     wf_type = wf_feature['attributes']['Assigned_Fire_Type']
#     if 'rings' in wf_feature['geometry']:
#         ring_data = wf_feature['geometry']['rings'][0]
#     elif 'curveRings' in wf_feature['geometry']:
#         ring_data = wf_feature['geometry']['curveRings'][0]
#     else:
#         raise Exception("HEY! No compatible geometry in this fire data!!!")
    
#     print(f"---------------Processing for {wf_name} and year {wf_year}---------------")
#     #
#     #     Compute using the shortest distance to any point on the perimeter
#     #
#     if wf_year >= 1961 and wf_year<=2021:
#         try:
#             distance = shortest_distance_from_place_to_fire_perimeter(place['latlon'],ring_data)
#             if distance[0] <= 650.0:
#                 print(f"The closest distance of fire '{wf_name}' ({wf_size:1.2f} acres) from {wf_year} was {distance[0]:1.2f} miles to {place['city']}")
#                 print(f"\tThe cloest perimiter point lat,lon {distance[1][0]},{distance[1][1]}")

#                 # Append data to shortest_dist_650_wf
#                 json_structure['wild_fire_name'] = wf_name
#                 json_structure['distance'] = distance[0]
#                 json_structure['size'] = wf_size
#                 json_structure['latlon'] = (distance[1][0], distance[1][1])
#                 json_structure['year'] = wf_year
                
#                 if shortest_dist_650_wf[wf_year]:
#                     shortest_dist_650_wf[wf_year].append(json_structure)
#                 else:
#                     shortest_dist_650_wf[wf_year] = []

#         except Exception as e:
#             # Append data to shortest_dist_650_wf
#             json_structure_error['wild_fire_name'] = wf_name
#             json_structure_error['error'] = str(e)
            
#             if shortest_error_wf[wf_year]:
#                     shortest_error_wf[wf_year].append(json_structure)
#             else:
#                 shortest_error_wf[wf_year] = []

#         #
#         #     Compute using the average distance to all points on the perimeter
#         #
#         try:
#             distance = average_distance_from_place_to_fire_perimeter(place['latlon'],ring_data)
#             if distance <= 650.0:
#                 print(f"Fire '{wf_name}' ({wf_size:1.2f} acres) from {wf_year} was an average {distance:1.2f} miles to {place['city']}")
#                 # just get a location to print thats on the ring (perimeter)
#                 ring = convert_ring_to_epsg4326(ring_data)
#                 perimeter_start = ring[0]
#                 # print(f"\tOne perimiter point lat,lon {perimeter_start[0]},{perimeter_start[1]}")
#                 # Append data to average_dist_650_wf
#                 json_structure['wild_fire_name'] = wf_name
#                 json_structure['distance'] = distance
#                 json_structure['size'] = wf_size
#                 json_structure['latlon'] = (perimeter_start[0], perimeter_start[1])
#                 json_structure['year'] = wf_year

#                 if avg_dist_650_wf[wf_year]:
#                     avg_dist_650_wf[wf_year].append(json_structure)
#                 else:
#                     avg_dist_650_wf[wf_year] = []
#         except Exception as e:
#             json_structure_error['wild_fire_name'] = wf_name
#             json_structure_error['error'] = str(e)

#             if avg_error_wf[wf_year]:
#                     avg_error_wf[wf_year].append(json_structure)
#             else:
#                 avg_error_wf[wf_year] = []

#     print()
